# %% [markdown]
# # Correctness, difficulty vs visits metrics
#
# ### Is there a statistically significant correlation between the correctness of the answer / the difficulty of the task and the total / average length of visits?
#
# ### Is there a statistically significant correlation between the correctness of the answer / the difficulty of the task and the number of visits?

# %%
import pandas as pd

from functions.tests.correlations import correlation_independent_groups_test, spearman_corr

# %%
names_sum = {1: 'Zsumowane_wszystkie_grafiki_z_poleceniem',
             2: 'Zsumowane_wszystkie_grafiki_bez_polecenia',
             3: 'Zsumowane_wszystkie_grafiki_tylko_polecenie',
             4: 'Zsumowane_grafiki_A_z_poleceniem',
             5: 'Zsumowane_grafiki_A_bez_polecenia',
             6: 'Zsumowane_grafiki_A_tylko_polecenie',
             7: 'Zsumowane_grafiki_B_z_poleceniem',
             8: 'Zsumowane_grafiki_B_bez_polecenia',
             9: 'Zsumowane_grafiki_B_tylko_polecenie',
             10: 'Zsumowane_grafiki_1_z_poleceniem',
             11: 'Zsumowane_grafiki_1_bez_polecenia',
             12: 'Zsumowane_grafiki_1_tylko_polecenie',
             13: 'Zsumowane_grafiki_2_z_poleceniem',
             14: 'Zsumowane_grafiki_2_bez_polecenia',
             15: 'Zsumowane_grafiki_2_tylko_polecenie',
             16: 'Zsumowane_grafiki_3_z_poleceniem',
             17: 'Zsumowane_grafiki_3_bez_polecenia',
             18: 'Zsumowane_grafiki_3_tylko_polecenie',
             }

names_samples = {
    1: '1a',
    2: '1b',
    3: '2a',
    4: '2b',
    5: '3a',
    6: '3b',
}

path = '/Users/martasolarz/Studies/Thesis/Master_thesis/prepare_datasets/sets/visit'

dfs_sum = [pd.read_csv(f'{path}/dfs_sum_{name}.csv') for _, name in names_sum.items()]

dfs_samples = [pd.read_csv(f'{path}/dfs_samples_{name}.csv') for _, name in names_samples.items()]

# %%
def print_nans(df):
    for col in df.filter(regex='Avg').columns:
        print(f"{col}: {df[col].isna().sum()} - for so many people there was no visit on this element")

# %%
# Check NaNs
for df, id in zip(dfs_samples, ['1a', '1b', '2a', '2b', '3a', '3b']):
    print(id)
    print_nans(df)
# Out:
# 1a
# Avg_map: 0 - for so many people there was no visit on this element
# Avg_com: 3 - for so many people there was no visit on this element
# 1b
# Avg_map: 1 - for so many people there was no visit on this element
# Avg_com: 3 - for so many people there was no visit on this element
# Avg_plt: 5 - for so many people there was no visit on this element
# Avg_tab: 1 - for so many people there was no visit on this element
# Avg_txt: 12 - for so many people there was no visit on this element
# 2a
# Avg_map: 0 - for so many people there was no visit on this element
# Avg_com: 1 - for so many people there was no visit on this element
# 2b
# Avg_map: 0 - for so many people there was no visit on this element
# Avg_com: 1 - for so many people there was no visit on this element
# Avg_plt: 5 - for so many people there was no visit on this element
# Avg_tab: 1 - for so many people there was no visit on this element
# Avg_txt: 1 - for so many people there was no visit on this element
# 3a
# Avg_map: 0 - for so many people there was no visit on this element
# Avg_com: 3 - for so many people there was no visit on this element
# 3b
# Avg_map: 0 - for so many people there was no visit on this element
# Avg_com: 1 - for so many people there was no visit on this element
# Avg_plt: 0 - for so many people there was no visit on this element
# Avg_tab: 0 - for so many people there was no visit on this element
# Avg_txt: 7 - for so many people there was no visit on this element

# %%
names_sum = {
    1: 'Zsumowane wszystkie grafiki: z poleceniem:',
    2: 'Zsumowane wszystkie grafiki: bez polecenia:',
    3: 'Zsumowane wszystkie grafiki: tylko polecenie:',
    4: 'Zsumowane grafiki A: z poleceniem:',
    5: 'Zsumowane grafiki A: bez polecenia:',
    6: 'Zsumowane grafiki A: tylko polecenie:',
    7: 'Zsumowane grafiki B: z poleceniem:',
    8: 'Zsumowane grafiki B: bez polecenia:',
    9: 'Zsumowane grafiki B: tylko polecenie:',
    10: 'Zsumowane grafiki 1: z poleceniem:',
    11: 'Zsumowane grafiki 1: bez polecenia:',
    12: 'Zsumowane grafiki 1: tylko polecenie:',
    13: 'Zsumowane grafiki 2: z poleceniem:',
    14: 'Zsumowane grafiki 2: bez polecenia:',
    15: 'Zsumowane grafiki 2: tylko polecenie:',
    16: 'Zsumowane grafiki 3: z poleceniem:',
    17: 'Zsumowane grafiki 3: bez polecenia:',
    18: 'Zsumowane grafiki 3: tylko polecenie:',
}

cols_continue = {
    'Total': 'Całkowity czas wizyty',
    'Avg': 'Średni czas wizyty',
}

names_samples = {
    1: '1a',
    2: '1b',
    3: '2a',
    4: '2b',
    5: '3a',
    6: '3b',
}

# %% [markdown]
# ### 1. Correctness
#
# ##### H0: There is no statistically significant correlation between the correctness of the answer and the given visit metric.
#
# ##### H1: There is a statistically significant correlation between the correctness of the answer and the given visit metric.
#
# ##### Significance level: $\alpha=0.05$

# %%
ALPHA = 0.05

# %% [markdown]
# Correctness vs total, average time of visits

# %%
results = []
param_category = 'Corr'
results.append(param_category)
for col in cols_continue:
    results.append('\n')
    results.append(col)
    print('##########################################')
    print(col)
    for i, df in enumerate(dfs_sum):
        print('------------------------------')
        print(names_sum[i+1])
        df = df.dropna()
        p = correlation_independent_groups_test(df[col], df[param_category], ALPHA)
        results.append(p)
# Out:
# ##########################################
# Total
# ------------------------------
# Zsumowane wszystkie grafiki: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.026641512450066383
# P-value: 0.8703754907113409
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.05241427992893495
# P-value: 0.7480541807000687
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: tylko polecenie:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.13175965396500225
# P-value: 0.41768796781358974
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.2423802743193968
# P-value: 0.13183384839546025
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.12509949642291449
# P-value: 0.44181099864986717
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: tylko polecenie:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.30302546288980003
# P-value: 0.057342858737628
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.18833436530025804
# P-value: 0.24450061613588236
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.16024941608881604
# P-value: 0.3232649874780483
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: tylko polecenie:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.2398578566844843
# P-value: 0.13602723036513764
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.06077763192527569
# P-value: 0.7094854943606059
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.010885546016467287
# P-value: 0.9468483791274847
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: tylko polecenie:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.09222476486173675
# P-value: 0.5713983297539076
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.5572226583556128
# P-value: 0.00018784754151907485
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 2: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.5504750402270877
# P-value: 0.00023300819887857565
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 2: tylko polecenie:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.1162331638913661
# P-value: 0.47507952954159216
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.4473534152924941
# P-value: 0.0038008988646199074
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 3: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.4809049214394312
# P-value: 0.0016828675264801269
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 3: tylko polecenie:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.08108280652176457
# P-value: 0.6189269650861193
# No reason to reject H0, accept H0.
# ##########################################
# Avg
# ------------------------------
# Zsumowane wszystkie grafiki: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.25550754875118015
# P-value: 0.1115488890338523
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.18504267886513498
# P-value: 0.25299399875191836
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: tylko polecenie:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.09903692671655112
# P-value: 0.5431873047877613
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.03859239272662025
# P-value: 0.8131006171587971
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.0729747062467001
# P-value: 0.654517802586871
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: tylko polecenie:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.2909100704333752
# P-value: 0.06858455674597352
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.3124450599772921
# P-value: 0.04966168986997804
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki B: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.15013057409351707
# P-value: 0.3551450535240025
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: tylko polecenie:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.14476139262662377
# P-value: 0.37280759386994033
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.016933071581171338
# P-value: 0.9174030455444951
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.04505406545704516
# P-value: 0.7825085753004133
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: tylko polecenie:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.042332678952928346
# P-value: 0.7953561851328177
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.5360003110158971
# P-value: 0.00036433649952799497
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 2: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.5485160543188063
# P-value: 0.00024783559722052045
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 2: tylko polecenie:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.12036880080884915
# P-value: 0.4593999401602229
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.3662706087707296
# P-value: 0.02010033936370709
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 3: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.43057766221902555
# P-value: 0.005546676730170588
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 3: tylko polecenie:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.06710301229387411
# P-value: 0.6807767875879321
# No reason to reject H0, accept H0.

# %% [markdown]
# Correctness vs number of visits

# %%
param_category = 'Corr'
col = 'Num'
results.append('\n')
results.append(col)
for i, df in enumerate(dfs_sum):
    print('------------------------------')
    print(names_sum[i+1])
    df = df.dropna()
    p= correlation_independent_groups_test(df[col], df[param_category], ALPHA)
    results.append(p)
# Out:
# ------------------------------
# Zsumowane wszystkie grafiki: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.0830874874549119
# P-value: 0.6102540075953254
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.21908292703994212
# P-value: 0.1743901455231313
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: tylko polecenie:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.016335334880411338
# P-value: 0.9203092178479954
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.3000683477111397
# P-value: 0.059940657650645414
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.32592952390605784
# P-value: 0.040129355718988124
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki A: tylko polecenie:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.21223532732720052
# P-value: 0.1885883806716101
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.07004958740572698
# P-value: 0.6675504826244651
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.21652487504290122
# P-value: 0.17960163154805284
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: tylko polecenie:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.10962366072697514
# P-value: 0.5007121980889924
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.0142384239249234
# P-value: 0.9305121525447562
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.11982340644827667
# P-value: 0.4614516456711122
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: tylko polecenie:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.0685924331723469
# P-value: 0.6740791347047106
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.2729329536277579
# P-value: 0.08838785899602732
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.14278584846018982
# P-value: 0.3794355135409888
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: tylko polecenie:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.009570550458246011
# P-value: 0.9532616608529512
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.2995331037560834
# P-value: 0.06042072150626256
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.009826964449111976
# P-value: 0.9520108798161735
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: tylko polecenie:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.1039047130531446
# P-value: 0.5234453710240755
# No reason to reject H0, accept H0.

# %% [markdown]
# ### Summary:
#
# Statistically significant:
#
# - total length of visit:
#     - sums: 2 (with command, without command), 3 (with command, without command)
# - average length of visit:
#     - sums: B (with command), 2 (with command, without command), 3 (with command, without command)
# - number of visits:
#     - sums: A (without command)
#         -
# Note: I used dropna()!

# %% [markdown]
# Each graphic separately

# %%
columns_sample = ['Total_map', 'Avg_map', 'Num_map', 'Total_com', 'Avg_com', 'Num_com', 'Total_plt', 'Avg_plt', 'Num_plt', 'Total_tab', 'Avg_tab', 'Num_tab',  'Total_txt', 'Avg_txt', 'Num_txt']

param_category = 'Corr'
for col in columns_sample:
    print('##########################################')
    results.append('\n')
    print(col)
    results.append(col)
    for i, df in enumerate(dfs_samples):
        if col not in df.columns:
            continue
        print('------------------------------')
        print(names_samples[i + 1])
        df = df.dropna()
        p = correlation_independent_groups_test(df[col], df[param_category], ALPHA, biserial=True)
        results.append(p)
# Out:
# ##########################################
# Total_map
# ------------------------------
# 1a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.2369395511036369
# P-value: 0.15795638506512769
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.11631052629980886
# P-value: 0.5971535274796473
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.6861374500709487
# P-value: 1.4253896122565885e-06
# There are grounds to reject H0, accept H1.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.013160039288194762
# P-value: 0.9411151052494134
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.42158602695271463
# P-value: 0.009355419323205485
# There are grounds to reject H0, accept H1.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.1624591083221647
# P-value: 0.3743437859785381
# No reason to reject H0, accept H0.
# ##########################################
# Avg_map
# ------------------------------
# 1a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.25174827304761427
# P-value: 0.13281490317491731
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.2326210525996177
# P-value: 0.2854585744862521
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.700946172014926
# P-value: 6.721675599231004e-07
# There are grounds to reject H0, accept H1.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.00657951694959769
# P-value: 0.9705406818661828
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.3657131800071741
# P-value: 0.026018428634601156
# There are grounds to reject H0, accept H1.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.10153694270135294
# P-value: 0.5802908670214688
# No reason to reject H0, accept H0.
# ##########################################
# Num_map
# ------------------------------
# 1a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.12477260473828009
# P-value: 0.46185523086537994
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.09441097989656858
# P-value: 0.6682954456549468
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.29514761071726825
# P-value: 0.06813664615701294
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.06618053290850719
# P-value: 0.7099900255655625
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.03888441728664343
# P-value: 0.8192631205205584
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.07824034486455876
# P-value: 0.6703711028157463
# No reason to reject H0, accept H0.
# ##########################################
# Total_com
# ------------------------------
# 1a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.2554655953761004
# P-value: 0.1269973442092539
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.11631052629980886
# P-value: 0.5971535274796473
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.2023858665676899
# P-value: 0.21660258886723063
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.026320078576389523
# P-value: 0.8825353066147595
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.09650764472411538
# P-value: 0.5698898872443461
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.013538259026847058
# P-value: 0.9413762360015461
# No reason to reject H0, accept H0.
# ##########################################
# Avg_com
# ------------------------------
# 1a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.15179839725246544
# P-value: 0.3697857188012419
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.20935894733965596
# P-value: 0.33768970564506584
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.07404360971988655
# P-value: 0.6541722977076485
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.11843130509275843
# P-value: 0.5047140774472346
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.13206309278036843
# P-value: 0.43588624182370017
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.03723362465254047
# P-value: 0.8396703133547285
# No reason to reject H0, accept H0.
# ##########################################
# Num_com
# ------------------------------
# 1a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.28031346581355326
# P-value: 0.09287232148328034
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.15492236297479373
# P-value: 0.480295440312297
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.19134226400260315
# P-value: 0.24326117879665843
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.22618818601110097
# P-value: 0.19833604437076596
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.20475778803232392
# P-value: 0.22410862222138267
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.14626188772224308
# P-value: 0.4244217930637433
# No reason to reject H0, accept H0.
# ##########################################
# Total_plt
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.20935894733965596
# P-value: 0.33768970564506584
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.592156525463792
# P-value: 0.00022491137898534967
# There are grounds to reject H0, accept H1.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.12861346075504704
# P-value: 0.4829764211012355
# No reason to reject H0, accept H0.
# ##########################################
# Avg_plt
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.02326210525996177
# P-value: 0.9160952206735584
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.5658384576654014
# P-value: 0.0004871785873581348
# There are grounds to reject H0, accept H1.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.15568997880874116
# P-value: 0.39483517796552114
# No reason to reject H0, accept H0.
# ##########################################
# Num_plt
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.23656955765158216
# P-value: 0.2771262977706521
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.17308914443538145
# P-value: 0.32761040107679074
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.17638574009200855
# P-value: 0.3341991471384682
# No reason to reject H0, accept H0.
# ##########################################
# Total_tab
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.3721936841593883
# P-value: 0.08030850990329397
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.2500216440847123
# P-value: 0.15383994828104147
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.2572269215100941
# P-value: 0.1552448156768965
# No reason to reject H0, accept H0.
# ##########################################
# Avg_tab
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.3721936841593883
# P-value: 0.08030850990329397
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.296078262731896
# P-value: 0.0890930148541907
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.21661214442955293
# P-value: 0.2337345437058444
# No reason to reject H0, accept H0.
# ##########################################
# Num_tab
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.22309418674798373
# P-value: 0.306201048722583
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.07659461151290269
# P-value: 0.6667974322730357
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.071291787051366
# P-value: 0.6982113371274032
# No reason to reject H0, accept H0.
# ##########################################
# Total_txt
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.0
# P-value: 1.0
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.02631806779839076
# P-value: 0.8825442185647843
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.37924506689847887
# P-value: 0.03230008990553538
# There are grounds to reject H0, accept H1.
# ##########################################
# Avg_txt
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.06980356187326113
# P-value: 0.7516354399288809
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.05921565254637921
# P-value: 0.7393904668797064
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.45022964030173973
# P-value: 0.009718339967783218
# There are grounds to reject H0, accept H1.
# ##########################################
# Num_txt
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.03660620142482148
# P-value: 0.8682970015741428
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.0931217672921781
# P-value: 0.6004044275233414
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.04201664188593293
# P-value: 0.8193926068148247
# No reason to reject H0, accept H0.

# %% [markdown]
# ### Summary:
#
# Statistically significant:
# - total length of fixation:
#     - map: 2a, 3a; plot: 2b, text: 3b
# - average length of fixation:
#     - map: 2a, 3a; plot: 2b, text: 3b

# %% [markdown]
# ### 2. Difficulty:
#
# ##### H0: There is no statistically significant correlation between the difficulty of the task and the given visit metric.
#
# ##### H1: There is a statistically significant correlation between the difficulty of the task and the given visit metric.
#
# ##### Significance level: $\alpha=0.05$
#
# Difficulty vs total, average time of visits

# %%
results.append('\n')
param_category = 'Diff'
results.append(param_category)
for col in cols_continue:
    results.append('\n')
    print('##########################################')
    print(col)
    results.append(col)
    for i, df in enumerate(dfs_sum):
        print('------------------------------')
        print(names_sum[i + 1])
        df = df.dropna()
        p = spearman_corr(df[col], df[param_category], ALPHA)
        results.append(p)
# Out:
# ##########################################
# Total
# ------------------------------
# Zsumowane wszystkie grafiki: z poleceniem:
# Spearman correlation test statistic value: 0.2192711110940766
# P-value: 0.1740110870482745
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: bez polecenia:
# Spearman correlation test statistic value: 0.1984375274518621
# P-value: 0.21964095885594784
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: tylko polecenie:
# Spearman correlation test statistic value: 0.12650981560113964
# P-value: 0.4366399415267119
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: z poleceniem:
# Spearman correlation test statistic value: 0.3276511410726209
# P-value: 0.03902764959972251
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki A: bez polecenia:
# Spearman correlation test statistic value: 0.3672253463886746
# P-value: 0.019753895861948707
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki A: tylko polecenie:
# Spearman correlation test statistic value: 0.04161111294261526
# P-value: 0.7987717876310096
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: z poleceniem:
# Spearman correlation test statistic value: 0.35043636023739955
# P-value: 0.026629819479641426
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki B: bez polecenia:
# Spearman correlation test statistic value: 0.3189332545234997
# P-value: 0.04486983209548784
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki B: tylko polecenie:
# Spearman correlation test statistic value: 0.22604192166317869
# P-value: 0.16076298458431754
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: z poleceniem:
# Spearman correlation test statistic value: 0.13494360189263233
# P-value: 0.4064244219845111
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: bez polecenia:
# Spearman correlation test statistic value: 0.0606226116493899
# P-value: 0.7101942677534019
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: tylko polecenie:
# Spearman correlation test statistic value: 0.2166481153495825
# P-value: 0.17934803661188772
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: z poleceniem:
# Spearman correlation test statistic value: 0.6965360673086721
# P-value: 5.985589801931188e-07
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 2: bez polecenia:
# Spearman correlation test statistic value: 0.6655980654191369
# P-value: 2.78075245926692e-06
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 2: tylko polecenie:
# Spearman correlation test statistic value: 0.3213529298433162
# P-value: 0.04318157830691164
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 3: z poleceniem:
# Spearman correlation test statistic value: 0.5288569949624891
# P-value: 0.0004509446964657781
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 3: bez polecenia:
# Spearman correlation test statistic value: 0.5372018785121929
# P-value: 0.00035133388910890277
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 3: tylko polecenie:
# Spearman correlation test statistic value: -0.02636224575929208
# P-value: 0.8717229066208239
# No reason to reject H0, accept H0.
# ##########################################
# Avg
# ------------------------------
# Zsumowane wszystkie grafiki: z poleceniem:
# Spearman correlation test statistic value: 0.1713821495997555
# P-value: 0.2903322551944792
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: bez polecenia:
# Spearman correlation test statistic value: 0.11010690359324225
# P-value: 0.49881458150431757
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: tylko polecenie:
# Spearman correlation test statistic value: 0.10190544758929354
# P-value: 0.531510687229743
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: z poleceniem:
# Spearman correlation test statistic value: 0.24025810433300235
# P-value: 0.13535532516526666
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: bez polecenia:
# Spearman correlation test statistic value: 0.24423492398486066
# P-value: 0.12881248558352884
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: tylko polecenie:
# Spearman correlation test statistic value: 0.08215912797933225
# P-value: 0.6142639863611767
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: z poleceniem:
# Spearman correlation test statistic value: 0.3434885453820682
# P-value: 0.03000455202668434
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki B: bez polecenia:
# Spearman correlation test statistic value: 0.27467662565049844
# P-value: 0.08629251087918378
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: tylko polecenie:
# Spearman correlation test statistic value: 0.13581550408983412
# P-value: 0.40337062019072223
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: z poleceniem:
# Spearman correlation test statistic value: 0.13552651162003032
# P-value: 0.40438133970435775
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: bez polecenia:
# Spearman correlation test statistic value: 0.202852585134497
# P-value: 0.20934434444227007
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: tylko polecenie:
# Spearman correlation test statistic value: 0.09209973692888082
# P-value: 0.5719222910576289
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: z poleceniem:
# Spearman correlation test statistic value: 0.547114138678099
# P-value: 0.00025896198465841306
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 2: bez polecenia:
# Spearman correlation test statistic value: 0.5531484857958722
# P-value: 0.00021406164765264436
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 2: tylko polecenie:
# Spearman correlation test statistic value: 0.2011449039257717
# P-value: 0.2132863684799619
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: z poleceniem:
# Spearman correlation test statistic value: 0.2447516413839312
# P-value: 0.12797998556369458
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: bez polecenia:
# Spearman correlation test statistic value: 0.251768929823455
# P-value: 0.11706824253554332
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: tylko polecenie:
# Spearman correlation test statistic value: -0.15855278744437543
# P-value: 0.32848134102217297
# No reason to reject H0, accept H0.

# %% [markdown]
# Difficulty vs number of visits

# %%
param_category = 'Diff'
col = 'Num'
results.append('\n')
results.append(col)
for i, df in enumerate(dfs_sum):
    print('------------------------------')
    print(names_sum[i + 1])
    df = df.dropna()
    p = spearman_corr(df[col], df[param_category], ALPHA)
    results.append(p)
# Out:
# ------------------------------
# Zsumowane wszystkie grafiki: z poleceniem:
# Spearman correlation test statistic value: 0.07246366701299503
# P-value: 0.6567875675728048
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: bez polecenia:
# Spearman correlation test statistic value: 0.05556884254589089
# P-value: 0.7334294835397859
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: tylko polecenie:
# Spearman correlation test statistic value: 0.07754803862097552
# P-value: 0.6343438270173737
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: z poleceniem:
# Spearman correlation test statistic value: -0.009485588552916091
# P-value: 0.9536761274242529
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: bez polecenia:
# Spearman correlation test statistic value: 0.12258811573863417
# P-value: 0.45110195520818497
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: tylko polecenie:
# Spearman correlation test statistic value: -0.18718693972695977
# P-value: 0.24743916543000016
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: z poleceniem:
# Spearman correlation test statistic value: 0.15611003369581009
# P-value: 0.33608313264706247
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: bez polecenia:
# Spearman correlation test statistic value: 0.014883029849066694
# P-value: 0.9273744522857226
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: tylko polecenie:
# Spearman correlation test statistic value: 0.17773847968066675
# P-value: 0.2725381843056638
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: z poleceniem:
# Spearman correlation test statistic value: -0.037717083494037774
# P-value: 0.8172668873344737
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: bez polecenia:
# Spearman correlation test statistic value: -0.2970025696191006
# P-value: 0.06273193498715253
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: tylko polecenie:
# Spearman correlation test statistic value: 0.28009682357155685
# P-value: 0.08002437826476118
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: z poleceniem:
# Spearman correlation test statistic value: 0.3830377722066416
# P-value: 0.014704613952437363
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 2: bez polecenia:
# Spearman correlation test statistic value: 0.2638927586095273
# P-value: 0.09988864294042873
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: tylko polecenie:
# Spearman correlation test statistic value: 0.026279823480786158
# P-value: 0.8721206490504135
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: z poleceniem:
# Spearman correlation test statistic value: 0.4753375280299506
# P-value: 0.0019374912065873925
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 3: bez polecenia:
# Spearman correlation test statistic value: 0.29977326499317203
# P-value: 0.060204942394176474
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: tylko polecenie:
# Spearman correlation test statistic value: 0.25682706086281987
# P-value: 0.10964868802969958
# No reason to reject H0, accept H0.

# %% [markdown]
# Podsumowanie - trudność:
#
# Istotne statystycznie:
#
# - całkowita długość wizyty:
#     - sumy: A (z poleceniem, bez polecenia), B (z poleceniem, bez polecenia), 2 (z poleceniem, bez polecenia, tylko polecenie), 3 (z poleceniem, bez polecenia)
# - średnia długość wizyty:
#     - sumy: B (z poleceniem), 2 (z poleceniem, bez polecenia)
# - liczba wizyt:
#     - sumy: 2 (z poleceniem), 3 (z poleceniem)
#
# ### Summary:
#
# Statistically significant:
#
# - total length of visit:
#     - sums: A (with command, without command), B (with command, without command), 2 (with command, without command, only command), 3 (with command, without command)
# - average length of visit:
# - number of visits:
#     - sums: B (with command), 2 (with command, without command)
# - number of visits:
#     - sums: 2 (with command), 3 (with command)

# %% [markdown]
# Each graphic separately

# %%
columns_sample = ['Total_map', 'Avg_map', 'Num_map', 'Total_com', 'Avg_com', 'Num_com', 'Total_plt', 'Avg_plt', 'Num_plt', 'Total_tab', 'Avg_tab', 'Num_tab',  'Total_txt', 'Avg_txt', 'Num_txt']

param_category = 'Diff'
for col in columns_sample:
    results.append('\n')
    print('##########################################')
    print(col)
    results.append(col)
    for i, df in enumerate(dfs_samples):
        if col not in df.columns:
            continue
        print('------------------------------')
        print(names_samples[i+1])
        df = df.dropna()
        p = spearman_corr(df[col], df[param_category], ALPHA)
        results.append(p)
# Out:
# ##########################################
# Total_map
# ------------------------------
# 1a
# Spearman correlation test statistic value: 0.20564163107429215
# P-value: 0.22207167952632187
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Spearman correlation test statistic value: 0.011459415165127246
# P-value: 0.9586130555182791
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Spearman correlation test statistic value: 0.7243867316685648
# P-value: 1.856282086478198e-07
# There are grounds to reject H0, accept H1.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.5404109272212296
# P-value: 0.0009691539252637154
# There are grounds to reject H0, accept H1.
# ------------------------------
# 3a
# Spearman correlation test statistic value: 0.6598080238959351
# P-value: 8.900987772247571e-06
# There are grounds to reject H0, accept H1.
# ------------------------------
# 3b
# Spearman correlation test statistic value: -0.22283656292278534
# P-value: 0.22024106083466757
# No reason to reject H0, accept H0.
# ##########################################
# Avg_map
# ------------------------------
# 1a
# Spearman correlation test statistic value: 0.14589103608902568
# P-value: 0.38891579663809606
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Spearman correlation test statistic value: 0.18647593768707063
# P-value: 0.3942450604699592
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Spearman correlation test statistic value: 0.6867384476089232
# P-value: 1.3837377482337088e-06
# There are grounds to reject H0, accept H1.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.34368398166942205
# P-value: 0.04657608401391741
# There are grounds to reject H0, accept H1.
# ------------------------------
# 3a
# Spearman correlation test statistic value: 0.4191981128969159
# P-value: 0.009807656939748112
# There are grounds to reject H0, accept H1.
# ------------------------------
# 3b
# Spearman correlation test statistic value: -0.17397223129210632
# P-value: 0.3409603327981884
# No reason to reject H0, accept H0.
# ##########################################
# Num_map
# ------------------------------
# 1a
# Spearman correlation test statistic value: 0.03432515249141779
# P-value: 0.8401631673381535
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Spearman correlation test statistic value: -0.14481176043869504
# P-value: 0.509733836296762
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Spearman correlation test statistic value: 0.36951331776425966
# P-value: 0.02060513174754574
# There are grounds to reject H0, accept H1.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.3325237353186905
# P-value: 0.05467060259274268
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Spearman correlation test statistic value: 0.35832114927763026
# P-value: 0.02943141967002793
# There are grounds to reject H0, accept H1.
# ------------------------------
# 3b
# Spearman correlation test statistic value: -0.19195917412421035
# P-value: 0.29256573639365996
# No reason to reject H0, accept H0.
# ##########################################
# Total_com
# ------------------------------
# 1a
# Spearman correlation test statistic value: -0.18498884821814812
# P-value: 0.2730279309654321
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Spearman correlation test statistic value: 0.22710477327252182
# P-value: 0.2973589927393947
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Spearman correlation test statistic value: 0.31795399562974563
# P-value: 0.04854777621756252
# There are grounds to reject H0, accept H1.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.20313037055803856
# P-value: 0.2492381958001615
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Spearman correlation test statistic value: -0.09180683817537717
# P-value: 0.5889104048222498
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: 0.14088898730868935
# P-value: 0.4418173898065102
# No reason to reject H0, accept H0.
# ##########################################
# Avg_com
# ------------------------------
# 1a
# Spearman correlation test statistic value: -0.09249442410907406
# P-value: 0.5861108515381173
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Spearman correlation test statistic value: 0.2140827105848772
# P-value: 0.32665011635646635
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Spearman correlation test statistic value: 0.19087785475616573
# P-value: 0.24442860913226408
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.2647874740991205
# P-value: 0.13018537035478986
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Spearman correlation test statistic value: -0.2447773776184623
# P-value: 0.1442524284941515
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: -0.06645777896407427
# P-value: 0.7178118784129872
# No reason to reject H0, accept H0.
# ##########################################
# Num_com
# ------------------------------
# 1a
# Spearman correlation test statistic value: -0.03961102128736613
# P-value: 0.8159432342595657
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Spearman correlation test statistic value: 0.21214297030964327
# P-value: 0.3311567739435597
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Spearman correlation test statistic value: 0.2508629380755073
# P-value: 0.12345863319214005
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: -0.11532544881769899
# P-value: 0.5160301781348757
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Spearman correlation test statistic value: 0.16256289480679287
# P-value: 0.336397800661141
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: 0.28318284073794386
# P-value: 0.11629098977563126
# No reason to reject H0, accept H0.
# ##########################################
# Total_plt
# ------------------------------
# 1b
# Spearman correlation test statistic value: -0.03177383295785282
# P-value: 0.8855636460361931
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.2900280067020943
# P-value: 0.09613960547438422
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: 0.31980469183969706
# P-value: 0.07437422842208298
# No reason to reject H0, accept H0.
# ##########################################
# Avg_plt
# ------------------------------
# 1b
# Spearman correlation test statistic value: 0.25054448611028207
# P-value: 0.24888177354784238
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.325110759565347
# P-value: 0.0606380142212421
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: 0.2663771541423398
# P-value: 0.14056728878994218
# No reason to reject H0, accept H0.
# ##########################################
# Num_plt
# ------------------------------
# 1b
# Spearman correlation test statistic value: -0.21400847849690396
# P-value: 0.3268218994762834
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.09870195409473141
# P-value: 0.5786496436436719
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: 0.17626166670678245
# P-value: 0.33454471130318686
# No reason to reject H0, accept H0.
# ##########################################
# Total_tab
# ------------------------------
# 1b
# Spearman correlation test statistic value: 0.12813709684642283
# P-value: 0.5601191377904506
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.5014769968100251
# P-value: 0.002516152034120345
# There are grounds to reject H0, accept H1.
# ------------------------------
# 3b
# Spearman correlation test statistic value: 0.36676768760926015
# P-value: 0.03894361205634744
# There are grounds to reject H0, accept H1.
# ##########################################
# Avg_tab
# ------------------------------
# 1b
# Spearman correlation test statistic value: 0.17657917004446075
# P-value: 0.42025356760684296
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.5365597496732778
# P-value: 0.0010705491485305894
# There are grounds to reject H0, accept H1.
# ------------------------------
# 3b
# Spearman correlation test statistic value: 0.21085814699775507
# P-value: 0.2466930599245537
# No reason to reject H0, accept H0.
# ##########################################
# Num_tab
# ------------------------------
# 1b
# Spearman correlation test statistic value: -0.01708987027071197
# P-value: 0.938309441882361
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.2126021254520361
# P-value: 0.22736929025708066
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: 0.10050480686022914
# P-value: 0.584165681755089
# No reason to reject H0, accept H0.
# ##########################################
# Total_txt
# ------------------------------
# 1b
# Spearman correlation test statistic value: -0.16151348183186945
# P-value: 0.46157842581861097
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.288123060845266
# P-value: 0.09844388969702118
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: 0.18318259897273545
# P-value: 0.3156032442499229
# No reason to reject H0, accept H0.
# ##########################################
# Avg_txt
# ------------------------------
# 1b
# Spearman correlation test statistic value: -0.12191662822147566
# P-value: 0.5794696310193768
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.27542342179974466
# P-value: 0.11489291961842797
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: 0.24664847216175653
# P-value: 0.17355265909987347
# No reason to reject H0, accept H0.
# ##########################################
# Num_txt
# ------------------------------
# 1b
# Spearman correlation test statistic value: -0.14836244997329193
# P-value: 0.4992969531452406
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.3659827624055734
# P-value: 0.03328054990589384
# There are grounds to reject H0, accept H1.
# ------------------------------
# 3b
# Spearman correlation test statistic value: -0.10759285483498635
# P-value: 0.5577897875202618
# No reason to reject H0, accept H0.

# %% [markdown]
# ### Summary:
#
# Statistically significant:
# - total length of visit:
#     - map: 2a, 2b, 3a; command: 2a; table: 2b, 3b
# - average length of visit:
#     - map: 2a, 2b, 3a; table: 2b
# - number of visits:
#     - map: 2a, 3a; text: 2b

# %%
import csv
with open('./results/wizyty.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    row = []
    for item in results:
        if item != '\n':
            row.append(item)
        else:
            writer.writerow(row)
            row = []
    if row:
        writer.writerow(row)
