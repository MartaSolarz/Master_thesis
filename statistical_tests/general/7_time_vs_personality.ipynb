# %% [markdown]
# # Time and personal data
#
# ### Is there a statistically significant difference in response time depending on the personal characteristics of the respondents?

# %%
import pandas as pd

from functions.tests.independent_groups.two_groups import ttest_or_mannwhitney_test
from functions.tests.independent_groups.more_than_two_groups import anova_or_kruskalwallis_test
from functions.tests.posthoc import posthocNemenyi_test
from functions.others import choose_dominant_kind, change_to_ranges_roz, change_to_ranges_podst

# %%
df_quest = pd.read_csv(
    '/Users/martasolarz/Studies/Thesis/data/survey.csv',
).fillna('NO_VAL')

df_quest = df_quest[df_quest.ID != 6] # # rejected person due to eye tracking metrics

# change values to ranges
df_quest['MAT'] = df_quest['MAT_roz'].apply(lambda x: x if x == 'NO_VAL' else 'VAL' )
df_quest['POL'] = df_quest['JP_roz'].apply(lambda x: x if x == 'NO_VAL' else 'VAL' )
df_quest['HIST'] = df_quest['HIST_roz'].apply(lambda x: x if x == 'NO_VAL' else 'VAL')
df_quest['Typ_uczenia'] = df_quest.apply(choose_dominant_kind, axis=1)
df_quest['Kierunek_studiów'] = df_quest['Kierunek_studiów'].apply(lambda x: 'MISMaP Geografia' if x == 'Geografia, w ramach studiów międzyobszarowych' else x)
df_quest['JP_podst'] = df_quest['JP_podst'].apply(change_to_ranges_podst)
df_quest['MAT_podst'] = df_quest['MAT_podst'].apply(change_to_ranges_podst)
df_quest['JP_roz'] = df_quest['JP_roz'].apply(change_to_ranges_roz)
df_quest['MAT_roz'] = df_quest['MAT_roz'].apply(change_to_ranges_roz)
df_quest['HIST_roz'] = df_quest['HIST_roz'].apply(change_to_ranges_roz)
df_quest['FIZ_roz'] = df_quest['FIZ_roz'].apply(change_to_ranges_roz)

df_time = pd.read_csv('/Users/martasolarz/Studies/Thesis/Master_thesis/prepare_datasets/sets/times.csv')

df_merge = df_quest.merge(df_time, on='ID')
df_merge.head()
# Out:
#    ID Płeć  Rok_urodzenia         Kierunek_studiów  Rok_studiów Specjalność  \
# 0   1    M           2002         MISMaP Geografia            2    SPOŁ-EKO
# 1   2    M           2003  Gospodarka przestrzenna            1      NO_VAL
# 2   3    M           2001                Geografia            3     GEOINF
# 3   4    K           2000                Geografia            3     GEOINF
# 4   5    K           2002                Geografia            3     GEOINF
#
#    Wady_wzroku  Daltonizm Ilość_snu  JP_podst  ...  Duration_2a  Duration_2b  \
# 0            0          1         6         4  ...       54.481       58.697
# 1            1          1        <6         2  ...       42.248       85.329
# 2            0          1         8         2  ...       45.165       32.732
# 3            0          1         8         2  ...       12.449       37.715
# 4            0          1         7         2  ...       55.931       22.132
#
#    Duration_3a  Duration_3b  SumTime_all  SumTime_a  SumTime_b  SumTime_1  \
# 0       56.314       63.897      276.921    138.810    138.110     43.531
# 1       47.948      129.427      459.647    156.426    303.219    154.693
# 2        8.000       61.197      299.890    121.995    177.892    152.793
# 3       60.980      101.795      337.437    119.477    217.956    124.494
# 4       34.898       62.930      271.458    158.809    112.644     95.562
#
#    SumTime_2  SumTime_3
# 0    113.178    120.211
# 1    127.577    177.375
# 2     77.897     69.197
# 3     50.164    162.775
# 4     78.063     97.828
#
# [5 rows x 51 columns]

# %% [markdown]
# Prepare data for analysis:

# %%
df_sumAll = df_merge.rename(columns={'SumTime_all':'time'})
df_sumA = df_merge.rename(columns={'SumTime_a':'time'})
df_sumB = df_merge.rename(columns={'SumTime_b':'time'})
df_sum1 = df_merge.rename(columns={'SumTime_1':'time'})
df_sum2 = df_merge.rename(columns={'SumTime_2':'time'})
df_sum3 = df_merge.rename(columns={'SumTime_3':'time'})

# %%
dfs = [df_sumAll, df_sumA, df_sumB, df_sum1, df_sum2, df_sum3]
names = {
    1: 'Zsumowane wszystkie grafiki:',
    2: 'Zsumowane grafiki A:',
    3: 'Zsumowane grafiki B:',
    4: 'Zsumowane grafiki 1:',
    5: 'Zsumowane grafiki 2:',
    6: 'Zsumowane grafiki 3:',
}

columns = ['Płeć', 'Rok_urodzenia', 'Kierunek_studiów',
       'Rok_studiów', 'Specjalność', 'Wady_wzroku', 'Ilość_snu',
       'JP_podst', 'MAT_podst', 'JP_roz', 'MAT_roz', 'HIST_roz',
       'Samopocz', 'Stres', 'Zmęcz', 'Czyt_map', 'Podziel_uwg', 'Analit_myśl',
       'Spostrzeg', 'Czyt_ze_zroz', 'Wzrokowiec', 'Słuchowiec', 'Kinestetyk', 'MAT', 'POL', 'HIST', 'Typ_uczenia']

# %% [markdown]
# ##### H0: There is no statistically significant relationship between response time and the value of feature X.
#
# ##### H1: There is a statistically significant relationship between response time and the value of feature X.
#
# ##### Significance level: $\alpha=0.05$

# %%
ALPHA = 0.05

# %%
results = []
for col in columns:
    print('################################################')
    print(col)
    results.append('\n')
    results.append(col)
    for i, df in enumerate(dfs):
        print('-------------------------')
        print(names[i+1])
        if col in ['Płeć', 'Wady_wzroku', 'POL', 'MAT', 'HIST']:
            if col == 'Płeć':
                var1, var2 = 'K', 'M'
            elif col == 'Wady_wzroku':
                var1, var2 = 0, 1
            else:
                var1, var2 = 'VAL', 'NO_VAL'
            p = ttest_or_mannwhitney_test(df, 'time', col, ALPHA, var1, var2)
        else:
            p = anova_or_kruskalwallis_test(df, 'time', col, ALPHA)
        results.append(p)
# Out:
# ################################################
# Płeć
# -------------------------
# Zsumowane wszystkie grafiki:
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 217.0
# p-value: 0.5655940812648745
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: -0.17229982625247858
# p-value: 0.8641162144260317
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: 0.9123909929338637
# p-value: 0.36731531323404243
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: 0.7749353237769052
# p-value: 0.44317351959209583
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: 0.7512986570400323
# p-value: 0.4571008221635642
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: 0.024218066148079885
# p-value: 0.9808053992607025
# No reason to reject H0, accept H0.
# ################################################
# Rok_urodzenia
# -------------------------
# Zsumowane wszystkie grafiki:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.8952197730533413
# p-value: 0.42037199701728767
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.568390504760657
# p-value: 0.33451498343154473
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.526887961392987
# p-value: 0.6398276459608175
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 5.708543106821423
# p-value: 0.22199741845630916
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 10.286820138254853
# p-value: 0.03586368356767013
# There are grounds to reject H0, accept H1.
# -------------------------
# Zsumowane grafiki 3:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.8555122603365106
# p-value: 0.762311944957796
# No reason to reject H0, accept H0.
# ################################################
# Kierunek_studiów
# -------------------------
# Zsumowane wszystkie grafiki:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 2.548231707317072
# p-value: 0.27967813533950237
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 0.4012042682926875
# p-value: 0.8182379157268812
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 4.256036585365862
# p-value: 0.11907302808816031
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 0.6754725609756065
# p-value: 0.7133833962145344
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.8380487804878243
# p-value: 0.3989080298687557
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 2.749984756097561
# p-value: 0.25284152294315637
# No reason to reject H0, accept H0.
# ################################################
# Rok_studiów
# -------------------------
# Zsumowane wszystkie grafiki:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 0.7973665606221516
# p-value: 0.6712032509771981
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 0.2608297985153598
# p-value: 0.8777311853459346
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 0.6514492753623387
# p-value: 0.722003972749608
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 4.083912159773789
# p-value: 0.12977461293131978
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 2.0494167550371287
# p-value: 0.3589011137796912
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 0.09747260516085987
# p-value: 0.95243225051387
# No reason to reject H0, accept H0.
# ################################################
# Specjalność
# -------------------------
# Zsumowane wszystkie grafiki:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 4.207581300813018
# p-value: 0.23990394854689248
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 1.4135772357723653
# p-value: 0.7023552606411547
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 5.853902439024381
# p-value: 0.11893861938591649
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 0.6657926829268206
# p-value: 0.8812188074221662
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 3.228292682926849
# p-value: 0.35774830753747267
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 3.0924390243902593
# p-value: 0.3775913219665618
# No reason to reject H0, accept H0.
# ################################################
# Wady_wzroku
# -------------------------
# Zsumowane wszystkie grafiki:
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: -0.8035741735447186
# p-value: 0.4266412069474077
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: -0.3477490500933714
# p-value: 0.7299476048649689
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: -0.8808100066472859
# p-value: 0.38395779469159463
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: 0.5779620767513125
# p-value: 0.5666991684259826
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: -0.9660294529052444
# p-value: 0.34013758683554096
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: -1.0171976860327963
# p-value: 0.31549233792207987
# No reason to reject H0, accept H0.
# ################################################
# Ilość_snu
# -------------------------
# Zsumowane wszystkie grafiki:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 1.9921544715447226
# p-value: 0.7372019829464274
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 2.9225314116777668
# p-value: 0.5708721649468973
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 3.4168070953436995
# p-value: 0.49064021318235007
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 2.299157427937928
# p-value: 0.6809224622214367
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 1.1245269770879673
# p-value: 0.8903614592612786
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 1.1498706577974929
# p-value: 0.8862810925483545
# No reason to reject H0, accept H0.
# ################################################
# JP_podst
# -------------------------
# Zsumowane wszystkie grafiki:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 4.746058933892513
# p-value: 0.1913647320185668
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 2.5134709193245897
# p-value: 0.47286150504447055
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 4.595082220505475
# p-value: 0.20396435983653208
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 9.308747378876518
# p-value: 0.02545547042798095
# There are grounds to reject H0, accept H1.
# -------------------------
# Zsumowane grafiki 2:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.7394945370268289
# p-value: 0.8638774254424987
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 4.662399293676202
# p-value: 0.19825405726093343
# No reason to reject H0, accept H0.
# ################################################
# MAT_podst
# -------------------------
# Zsumowane wszystkie grafiki:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.934756097560978
# p-value: 0.40179427747791785
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.1783536585365937
# p-value: 0.36493552602244705
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.82926829268294
# p-value: 0.6085866331276082
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.8765243902438868
# p-value: 0.8310889969609887
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.0036585365853483
# p-value: 0.8003666991385853
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.764024390243904
# p-value: 0.4294564337170613
# No reason to reject H0, accept H0.
# ################################################
# JP_roz
# -------------------------
# Zsumowane wszystkie grafiki:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 9.593044846577499
# p-value: 0.022361845474573892
# There are grounds to reject H0, accept H1.
# -------------------------
# Zsumowane grafiki A:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.348072383949642
# p-value: 0.22624885145446497
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 9.681699449252562
# p-value: 0.021474914768729227
# There are grounds to reject H0, accept H1.
# -------------------------
# Zsumowane grafiki 1:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 12.039685287175473
# p-value: 0.00724844449659603
# There are grounds to reject H0, accept H1.
# -------------------------
# Zsumowane grafiki 2:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.963839496459471
# p-value: 0.5799457714665246
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 8.38360346184109
# p-value: 0.03871464013135794
# There are grounds to reject H0, accept H1.
# ################################################
# MAT_roz
# -------------------------
# Zsumowane wszystkie grafiki:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.4894308943089385
# p-value: 0.8285119883037965
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.7360975609756366
# p-value: 0.9468038796823189
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.548211382113834
# p-value: 0.6360241028664828
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.4184552845528486
# p-value: 0.6592946873159553
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.091951219512211
# p-value: 0.7188512241130882
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.025284552845534
# p-value: 0.7311081718654379
# No reason to reject H0, accept H0.
# ################################################
# HIST_roz
# -------------------------
# Zsumowane wszystkie grafiki:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.2056910569105668
# p-value: 0.5472521967337031
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.0270325203251929
# p-value: 0.5983877880727191
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.4221544715447152
# p-value: 0.49111486590282094
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.0512195121951464
# p-value: 0.35857775376053874
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.921341463414663
# p-value: 0.3826361536848455
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.9262195121951322
# p-value: 0.3817040319693088
# No reason to reject H0, accept H0.
# ################################################
# Samopocz
# -------------------------
# Zsumowane wszystkie grafiki:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 8.543495934959367
# p-value: 0.03601836254852611
# There are grounds to reject H0, accept H1.
# -------------------------
# Zsumowane grafiki A:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 3.185569105691073
# p-value: 0.3638894416897927
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 8.15044715447155
# p-value: 0.043002622026647896
# There are grounds to reject H0, accept H1.
# -------------------------
# Zsumowane grafiki 1:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 1.828252032520325
# p-value: 0.6088063599717628
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 10.235203252032562
# p-value: 0.016669074776312104
# There are grounds to reject H0, accept H1.
# -------------------------
# Zsumowane grafiki 3:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 11.61934959349594
# p-value: 0.008807641504811248
# There are grounds to reject H0, accept H1.
# ################################################
# Stres
# -------------------------
# Zsumowane wszystkie grafiki:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.5560162601626217
# p-value: 0.6346340812997542
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.5856910569105764
# p-value: 0.9646403867114008
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.147642276422772
# p-value: 0.7086253785482413
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.53357723577237
# p-value: 0.47279125277081757
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 5.456178861788601
# p-value: 0.24360833071714683
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.6786178861788557
# p-value: 0.6129613590731904
# No reason to reject H0, accept H0.
# ################################################
# Zmęcz
# -------------------------
# Zsumowane wszystkie grafiki:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 4.438495934959349
# p-value: 0.34990269211850245
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.3687804878048837
# p-value: 0.8496025571720354
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 4.009227642276414
# p-value: 0.4047584645906688
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 3.0236585365853728
# p-value: 0.55387403682436
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 2.504593495934955
# p-value: 0.6438134456473479
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 4.813902439024375
# p-value: 0.3069306665798468
# No reason to reject H0, accept H0.
# ################################################
# Czyt_map
# -------------------------
# Zsumowane wszystkie grafiki:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 2.9155609756097505
# p-value: 0.23275229842227332
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 4.099317073170752
# p-value: 0.12877886935348765
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.2731707317073244
# p-value: 0.5290960123038768
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.19946341463416672
# p-value: 0.9050802118628951
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 3.1715121951219487
# p-value: 0.20479289115817073
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 1.5844390243902637
# p-value: 0.4528385982708619
# No reason to reject H0, accept H0.
# ################################################
# Podziel_uwg
# -------------------------
# Zsumowane wszystkie grafiki:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.862311265969794
# p-value: 0.42496057726838077
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 6.244584785133554
# p-value: 0.1816119559997756
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.752206736353074
# p-value: 0.44057834825715936
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 9.345862369337965
# p-value: 0.05301262232429971
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.8863530778165085
# p-value: 0.5770204990934411
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.1599738675958235
# p-value: 0.7063634855454601
# No reason to reject H0, accept H0.
# ################################################
# Analit_myśl
# -------------------------
# Zsumowane wszystkie grafiki:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.6932275255766882
# p-value: 0.8747957358391074
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.3973003462092066
# p-value: 0.33432821335864504
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.503403742171386
# p-value: 0.4746762649646228
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 7.1298479013498195
# p-value: 0.06787224168543347
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.89870463297936
# p-value: 0.8257403996586831
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.5580114365736932
# p-value: 0.6689474642024007
# No reason to reject H0, accept H0.
# ################################################
# Spostrzeg
# -------------------------
# Zsumowane wszystkie grafiki:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.3630249771749021
# p-value: 0.7142243012642022
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 4.857734446328422
# p-value: 0.18251589328072207
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 1.5436774488065765
# p-value: 0.6722268987451185
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 2.389176014086331
# p-value: 0.49565268469767965
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 1.475275531498653
# p-value: 0.6879883677045575
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 3.6966479718273177
# p-value: 0.2961387381235028
# No reason to reject H0, accept H0.
# ################################################
# Czyt_ze_zroz
# -------------------------
# Zsumowane wszystkie grafiki:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.2310642549703061
# p-value: 0.8729580871977703
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.8576245132199034
# p-value: 0.4256170464798683
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.3649851403976214
# p-value: 0.985241971173768
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 11.834689485550342
# p-value: 0.018623840820634015
# There are grounds to reject H0, accept H1.
# -------------------------
# Zsumowane grafiki 2:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.38201475712233446
# p-value: 0.9839227481969404
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.7888117442098519
# p-value: 0.939941682360534
# No reason to reject H0, accept H0.
# ################################################
# Wzrokowiec
# -------------------------
# Zsumowane wszystkie grafiki:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.0279558652729293
# p-value: 0.5666246822033152
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 6.21759581881534
# p-value: 0.10149051220621683
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.6928222996515814
# p-value: 0.8748909043471589
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.7466666666666697
# p-value: 0.2901509363848614
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.2925087108013855
# p-value: 0.7309127213482115
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.9878397212543746
# p-value: 0.5749344484169965
# No reason to reject H0, accept H0.
# ################################################
# Słuchowiec
# -------------------------
# Zsumowane wszystkie grafiki:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 3.294642857142847
# p-value: 0.5097814974564541
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 5.316498257839754
# p-value: 0.25633644065077704
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 2.1206794425087168
# p-value: 0.7135742101749725
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 5.727351916376307
# p-value: 0.2204560536558053
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.40068815331012786
# p-value: 0.9824205237043964
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 2.554529616724764
# p-value: 0.6348987567425692
# No reason to reject H0, accept H0.
# ################################################
# Kinestetyk
# -------------------------
# Zsumowane wszystkie grafiki:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 6.235389765662376
# p-value: 0.18224535953480867
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.986355810616942
# p-value: 0.2887003416721836
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 7.0778718316595075
# p-value: 0.13182983576514767
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 5.610459110473471
# p-value: 0.23018930673160165
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 7.202333811573425
# p-value: 0.1255743884581814
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 6.886307986609296
# p-value: 0.14201969835476058
# No reason to reject H0, accept H0.
# ################################################
# MAT
# -------------------------
# Zsumowane wszystkie grafiki:
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 197.0
# p-value: 0.989154544586872
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: -0.020551655189258403
# p-value: 0.9837108426108379
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: 0.376841621192229
# p-value: 0.708387548456684
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: -0.35473675865321735
# p-value: 0.7247480408000636
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: 0.7126051117658688
# p-value: 0.4804431877422026
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: 0.1183771604302235
# p-value: 0.9063923757527197
# No reason to reject H0, accept H0.
# ################################################
# POL
# -------------------------
# Zsumowane wszystkie grafiki:
# Conducting normality test...
# Conducting homogeneity variance test...
# Mann-Whitney test conducted...
# U-statistic: 159.0
# p-value: 0.5382974190957754
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Conducting normality test...
# Conducting homogeneity variance test...
# Mann-Whitney test conducted...
# U-statistic: 166.0
# p-value: 0.39972517273408004
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Conducting normality test...
# Conducting homogeneity variance test...
# Mann-Whitney test conducted...
# U-statistic: 156.0
# p-value: 0.6043027795120417
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Conducting normality test...
# Conducting homogeneity variance test...
# Mann-Whitney test conducted...
# U-statistic: 152.0
# p-value: 0.6975223837436598
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Conducting normality test...
# Conducting homogeneity variance test...
# Mann-Whitney test conducted...
# U-statistic: 139.0
# p-value: 1.0
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Conducting normality test...
# Conducting homogeneity variance test...
# Mann-Whitney test conducted...
# U-statistic: 176.0
# p-value: 0.2436138556463281
# No reason to reject H0, accept H0.
# ################################################
# HIST
# -------------------------
# Zsumowane wszystkie grafiki:
# Conducting normality test...
# Conducting homogeneity variance test...
# Mann-Whitney test conducted...
# U-statistic: 80.0
# p-value: 0.7444359339096182
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Conducting normality test...
# Conducting homogeneity variance test...
# Mann-Whitney test conducted...
# U-statistic: 79.0
# p-value: 0.7775030090819565
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Conducting normality test...
# Conducting homogeneity variance test...
# Mann-Whitney test conducted...
# U-statistic: 89.0
# p-value: 0.4718240507714192
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Conducting normality test...
# Conducting homogeneity variance test...
# Mann-Whitney test conducted...
# U-statistic: 96.0
# p-value: 0.30217748112484955
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Conducting normality test...
# Conducting homogeneity variance test...
# Mann-Whitney test conducted...
# U-statistic: 57.0
# p-value: 0.5276944961155488
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Conducting normality test...
# Conducting homogeneity variance test...
# Mann-Whitney test conducted...
# U-statistic: 99.0
# p-value: 0.24260860050333735
# No reason to reject H0, accept H0.
# ################################################
# Typ_uczenia
# -------------------------
# Zsumowane wszystkie grafiki:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.880443458980039
# p-value: 0.18076393315820274
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki A:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.799290465631941
# p-value: 0.6150893505936275
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki B:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 6.794456762749462
# p-value: 0.078745841403815
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 1:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 5.473658536585361
# p-value: 0.1402226449708039
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 2:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.9161862527716238
# p-value: 0.8215200408021033
# No reason to reject H0, accept H0.
# -------------------------
# Zsumowane grafiki 3:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.409578713968969
# p-value: 0.33268019349857575
# No reason to reject H0, accept H0.

# %%
# posthoc tests
posthocNemenyi_test(df_sum2, 'time', 'Rok_urodzenia')
print()
posthocNemenyi_test(df_sum1, 'time', 'JP_podst')
# Out:
# +------+----------+----------+----------+----------+----------+
# |      |     2002 |     2003 |     2001 |     2000 |     2004 |
# +======+==========+==========+==========+==========+==========+
# | 2002 | 1        | 0.764018 | 0.960921 | 0.73919  | 0.584269 |
# +------+----------+----------+----------+----------+----------+
# | 2003 | 0.764018 | 1        | 0.364138 | 0.439093 | 0.151043 |
# +------+----------+----------+----------+----------+----------+
# | 2001 | 0.960921 | 0.364138 | 1        | 0.896714 | 0.882736 |
# +------+----------+----------+----------+----------+----------+
# | 2000 | 0.73919  | 0.439093 | 0.896714 | 1        | 0.998702 |
# +------+----------+----------+----------+----------+----------+
# | 2004 | 0.584269 | 0.151043 | 0.882736 | 0.998702 | 1        |
# +------+----------+----------+----------+----------+----------+
#
# +----+----------+----------+---------+----------+
# |    |        4 |        2 |       3 |        1 |
# +====+==========+==========+=========+==========+
# |  4 | 1        | 0.353282 | 0.09182 | 1        |
# +----+----------+----------+---------+----------+
# |  2 | 0.353282 | 1        | 0.83523 | 0.353282 |
# +----+----------+----------+---------+----------+
# |  3 | 0.09182  | 0.83523  | 1       | 0.09182  |
# +----+----------+----------+---------+----------+
# |  1 | 1        | 0.353282 | 0.09182 | 1        |
# +----+----------+----------+---------+----------+

# %%
posthocNemenyi_test(df_sumAll, 'time', 'JP_roz')
print()
posthocNemenyi_test(df_sumB, 'time', 'JP_roz')
print()
posthocNemenyi_test(df_sum1, 'time', 'JP_roz')
print()
posthocNemenyi_test(df_sum3, 'time', 'JP_roz')
# Out:
# +----+----------+----------+----------+----------+
# |    |        4 |        3 |        0 |        2 |
# +====+==========+==========+==========+==========+
# |  4 | 1        | 0.992107 | 0.073875 | 0.996057 |
# +----+----------+----------+----------+----------+
# |  3 | 0.992107 | 1        | 0.045699 | 0.97431  |
# +----+----------+----------+----------+----------+
# |  0 | 0.073875 | 0.045699 | 1        | 0.331673 |
# +----+----------+----------+----------+----------+
# |  2 | 0.996057 | 0.97431  | 0.331673 | 1        |
# +----+----------+----------+----------+----------+
#
# +----+----------+----------+----------+----------+
# |    |        4 |        3 |        0 |        2 |
# +====+==========+==========+==========+==========+
# |  4 | 1        | 0.992107 | 0.073875 | 0.996057 |
# +----+----------+----------+----------+----------+
# |  3 | 0.992107 | 1        | 0.045699 | 0.97431  |
# +----+----------+----------+----------+----------+
# |  0 | 0.073875 | 0.045699 | 1        | 0.331673 |
# +----+----------+----------+----------+----------+
# |  2 | 0.996057 | 0.97431  | 0.331673 | 1        |
# +----+----------+----------+----------+----------+
#
# +----+----------+----------+----------+----------+
# |    |        4 |        3 |        0 |        2 |
# +====+==========+==========+==========+==========+
# |  4 | 1        | 0.992107 | 0.073875 | 0.996057 |
# +----+----------+----------+----------+----------+
# |  3 | 0.992107 | 1        | 0.045699 | 0.97431  |
# +----+----------+----------+----------+----------+
# |  0 | 0.073875 | 0.045699 | 1        | 0.331673 |
# +----+----------+----------+----------+----------+
# |  2 | 0.996057 | 0.97431  | 0.331673 | 1        |
# +----+----------+----------+----------+----------+
#
# +----+----------+----------+----------+----------+
# |    |        4 |        3 |        0 |        2 |
# +====+==========+==========+==========+==========+
# |  4 | 1        | 0.992107 | 0.073875 | 0.996057 |
# +----+----------+----------+----------+----------+
# |  3 | 0.992107 | 1        | 0.045699 | 0.97431  |
# +----+----------+----------+----------+----------+
# |  0 | 0.073875 | 0.045699 | 1        | 0.331673 |
# +----+----------+----------+----------+----------+
# |  2 | 0.996057 | 0.97431  | 0.331673 | 1        |
# +----+----------+----------+----------+----------+

# %%
posthocNemenyi_test(df_sumAll, 'time', 'Samopocz')
print()
posthocNemenyi_test(df_sumB, 'time', 'Samopocz')
print()
posthocNemenyi_test(df_sum2, 'time', 'Samopocz')
print()
posthocNemenyi_test(df_sum3, 'time', 'Samopocz')
# Out:
# +----+----------+----------+----------+----------+
# |    |        4 |        3 |        5 |        2 |
# +====+==========+==========+==========+==========+
# |  4 | 1        | 0.066631 | 0.219529 | 0.04679  |
# +----+----------+----------+----------+----------+
# |  3 | 0.066631 | 1        | 0.90017  | 0.994794 |
# +----+----------+----------+----------+----------+
# |  5 | 0.219529 | 0.90017  | 1        | 0.793153 |
# +----+----------+----------+----------+----------+
# |  2 | 0.04679  | 0.994794 | 0.793153 | 1        |
# +----+----------+----------+----------+----------+
#
# +----+----------+----------+----------+----------+
# |    |        4 |        3 |        5 |        2 |
# +====+==========+==========+==========+==========+
# |  4 | 1        | 0.066631 | 0.219529 | 0.04679  |
# +----+----------+----------+----------+----------+
# |  3 | 0.066631 | 1        | 0.90017  | 0.994794 |
# +----+----------+----------+----------+----------+
# |  5 | 0.219529 | 0.90017  | 1        | 0.793153 |
# +----+----------+----------+----------+----------+
# |  2 | 0.04679  | 0.994794 | 0.793153 | 1        |
# +----+----------+----------+----------+----------+
#
# +----+----------+----------+----------+----------+
# |    |        4 |        3 |        5 |        2 |
# +====+==========+==========+==========+==========+
# |  4 | 1        | 0.066631 | 0.219529 | 0.04679  |
# +----+----------+----------+----------+----------+
# |  3 | 0.066631 | 1        | 0.90017  | 0.994794 |
# +----+----------+----------+----------+----------+
# |  5 | 0.219529 | 0.90017  | 1        | 0.793153 |
# +----+----------+----------+----------+----------+
# |  2 | 0.04679  | 0.994794 | 0.793153 | 1        |
# +----+----------+----------+----------+----------+
#
# +----+----------+----------+----------+----------+
# |    |        4 |        3 |        5 |        2 |
# +====+==========+==========+==========+==========+
# |  4 | 1        | 0.066631 | 0.219529 | 0.04679  |
# +----+----------+----------+----------+----------+
# |  3 | 0.066631 | 1        | 0.90017  | 0.994794 |
# +----+----------+----------+----------+----------+
# |  5 | 0.219529 | 0.90017  | 1        | 0.793153 |
# +----+----------+----------+----------+----------+
# |  2 | 0.04679  | 0.994794 | 0.793153 | 1        |
# +----+----------+----------+----------+----------+

# %%
posthocNemenyi_test(df_sum1, 'time', 'Czyt_ze_zroz')
# Out:
# +----+----------+----------+----------+----------+----------+
# |    |        4 |        2 |        3 |        1 |        5 |
# +====+==========+==========+==========+==========+==========+
# |  4 | 1        | 0.317559 | 0.213382 | 0.171966 | 0.45264  |
# +----+----------+----------+----------+----------+----------+
# |  2 | 0.317559 | 1        | 0.99895  | 0.86144  | 0.999045 |
# +----+----------+----------+----------+----------+----------+
# |  3 | 0.213382 | 0.99895  | 1        | 0.934242 | 0.98565  |
# +----+----------+----------+----------+----------+----------+
# |  1 | 0.171966 | 0.86144  | 0.934242 | 1        | 0.7678   |
# +----+----------+----------+----------+----------+----------+
# |  5 | 0.45264  | 0.999045 | 0.98565  | 0.7678   | 1        |
# +----+----------+----------+----------+----------+----------+

# %% [markdown]
# ### Summary:
# Significant statistically:
# - Year of birth: graphics 2 (poorly differentiated)
# - Matura: Polish language basic: graphics 1 (poorly differentiated)
# - Matura: Polish language extended: all graphics, graphics B, graphics 1, graphics 3 (for all: 0 vs 3)
# - Well-being: all, B, 2, 3 (for all: 2 vs 4)
# - Reading with understanding: graphics: 1 (poorly differentiated)

# %% [markdown]
# For each graphic separately:

# %%
columns = ['Płeć', 'Rok_urodzenia', 'Kierunek_studiów',
           'Rok_studiów', 'Specjalność', 'Wady_wzroku', 'Ilość_snu',
           'JP_podst', 'MAT_podst', 'JP_roz', 'MAT_roz', 'HIST_roz',
           'Samopocz', 'Stres', 'Zmęcz', 'Czyt_map', 'Podziel_uwg', 'Analit_myśl',
           'Spostrzeg', 'Czyt_ze_zroz', 'Wzrokowiec', 'Słuchowiec', 'Kinestetyk', 'MAT', 'POL', 'HIST', 'Typ_uczenia']

prefix = ['1a', '1b', '2a', '2b', '3a', '3b']
for col in columns:
    print('##############################################################')
    print(col)
    results.append('\n')
    results.append(col)
    for pref in prefix:
        print('-------------------------------------')
        print(pref)
        
        if col in ['Płeć', 'Wady_wzroku', 'POL', 'MAT', 'HIST']:
            if col == 'Płeć':
                var1, var2 = 'K', 'M'
            elif col == 'Wady_wzroku':
                var1, var2 = 0, 1
            else:
                var1, var2 = 'VAL', 'NO_VAL'
            p =ttest_or_mannwhitney_test(df_merge, f'Duration_{pref}', col, ALPHA, var1, var2)
        else:
            p = anova_or_kruskalwallis_test(df_merge, f'Duration_{pref}', col, ALPHA)
        
        results.append(p)
# Out:
# ##############################################################
# Płeć
# -------------------------------------
# 1a
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 199.0
# p-value: 0.9345839653717953
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 243.0
# p-value: 0.1984769534047992
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 215.0
# p-value: 0.6031799173850656
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: 0.80086999538444
# p-value: 0.42818608611489584
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: -0.2900437304152876
# p-value: 0.7733596749072188
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: 0.21715259625240219
# p-value: 0.8292511605326811
# No reason to reject H0, accept H0.
# ##############################################################
# Rok_urodzenia
# -------------------------------------
# 1a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.004936741880783
# p-value: 0.4053381466380622
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.7148575061953863
# p-value: 0.44596867269606144
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 7.961321246902315
# p-value: 0.09300536624810227
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 8.07904004173733
# p-value: 0.08872539067251924
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.7865723229425043
# p-value: 0.5941527861428131
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.0539921825496787
# p-value: 0.9015014528186495
# No reason to reject H0, accept H0.
# ##############################################################
# Kierunek_studiów
# -------------------------------------
# 1a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 2.2365243902439005
# p-value: 0.32684729820417013
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.49266768292683594
# p-value: 0.7816612304334447
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.4924390243902508
# p-value: 0.7817506022987855
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 4.00669207317074
# p-value: 0.13488320318759248
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 2.629207317073181
# p-value: 0.26858075183503666
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 3.3415329768270827
# p-value: 0.18810283172792377
# No reason to reject H0, accept H0.
# ##############################################################
# Rok_studiów
# -------------------------------------
# 1a
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 1.6981972428420136
# p-value: 0.42780036829866486
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.962173029339013
# p-value: 0.374903539286686
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.00989307175682086
# p-value: 0.9950656780829563
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 3.8785966772711333
# p-value: 0.14380481667024078
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.2461956521738955
# p-value: 0.884177162737921
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 0.0025795544624052265
# p-value: 0.9987110541739695
# No reason to reject H0, accept H0.
# ##############################################################
# Specjalność
# -------------------------------------
# 1a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.777987804878066
# p-value: 0.854724487713707
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.5013821138211512
# p-value: 0.6819513759390811
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.32658536585367415
# p-value: 0.9549533478216389
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 5.501890243902437
# p-value: 0.13852560357103721
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 1.0690447154471627
# p-value: 0.7845515718456596
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 4.064263376802075
# p-value: 0.2546079381678337
# No reason to reject H0, accept H0.
# ##############################################################
# Wady_wzroku
# -------------------------------------
# 1a
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 206.0
# p-value: 0.7093669722488405
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 209.0
# p-value: 0.648727957492339
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 208.0
# p-value: 0.6687077902918426
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: -1.5856801321745388
# p-value: 0.12109961260561179
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: -0.8713844967549311
# p-value: 0.38901645742335167
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: -0.9066270686379857
# p-value: 0.3703174235053397
# No reason to reject H0, accept H0.
# ##############################################################
# Ilość_snu
# -------------------------------------
# 1a
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 4.4298152254249885
# p-value: 0.350950885814388
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 5.458702882483379
# p-value: 0.24338344921226604
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.5936511456023794
# p-value: 0.8099327694117915
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 1.8680413895048247
# p-value: 0.7600131089089536
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 1.7123170731707376
# p-value: 0.7884790144531502
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 4.071307644414884
# p-value: 0.39644141924285653
# No reason to reject H0, accept H0.
# ##############################################################
# JP_podst
# -------------------------------------
# 1a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 4.405738880918207
# p-value: 0.2208538492052262
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 10.239267189051986
# p-value: 0.016638031964503173
# There are grounds to reject H0, accept H1.
# -------------------------------------
# 2a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.4075135194790818
# p-value: 0.7037744693917044
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 0.5027789427215623
# p-value: 0.9182804672629851
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 2.6959938196667252
# p-value: 0.4409085321137881
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 5.52218340755949
# p-value: 0.13731780804703173
# No reason to reject H0, accept H0.
# ##############################################################
# MAT_podst
# -------------------------------------
# 1a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.247256097560978
# p-value: 0.23597303533776473
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.2881097560975547
# p-value: 0.7319584506268082
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.4810975609756127
# p-value: 0.4787168651559678
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.890548780487805
# p-value: 0.8277079864063818
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 5.597560975609753
# p-value: 0.13291844998179614
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.457014025705973
# p-value: 0.4831097232152872
# No reason to reject H0, accept H0.
# ##############################################################
# JP_roz
# -------------------------------------
# 1a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 5.278520849724629
# p-value: 0.15250222837114255
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 13.3120692368214
# p-value: 0.004008116139617998
# There are grounds to reject H0, accept H1.
# -------------------------------------
# 2a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.3779386309992248
# p-value: 0.4977545512915259
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.8707789142407734
# p-value: 0.4119805880601547
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.96619984264359
# p-value: 0.1742889551458128
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 9.063005971025575
# p-value: 0.02846481131149232
# There are grounds to reject H0, accept H1.
# ##############################################################
# MAT_roz
# -------------------------------------
# 1a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.482439024390274
# p-value: 0.8297475547278523
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.758455284552866
# p-value: 0.3129911176074157
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.835365853658544
# p-value: 0.5857434911913392
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.3412195121951243
# p-value: 0.8543442418621655
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.0521951219512147
# p-value: 0.9017808958629019
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.8248788191512824
# p-value: 0.5875458632749859
# No reason to reject H0, accept H0.
# ##############################################################
# HIST_roz
# -------------------------------------
# 1a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.9928861788617951
# p-value: 0.6086918763752722
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.180487804878055
# p-value: 0.3361344996835547
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.7262195121951294
# p-value: 0.6955100928361384
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.1245934959349597
# p-value: 0.34566100173875663
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.2953252032520624
# p-value: 0.5232674329030916
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.5393720486599671
# p-value: 0.4631584659740473
# No reason to reject H0, accept H0.
# ##############################################################
# Samopocz
# -------------------------------------
# 1a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 2.1072764227642153
# p-value: 0.5504420967061547
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.9095934959349705
# p-value: 0.5913812458957208
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 5.57008130081303
# p-value: 0.13450655103125636
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 9.48475609756099
# p-value: 0.023494084147203435
# There are grounds to reject H0, accept H1.
# -------------------------------------
# 3a
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 12.633780487804898
# p-value: 0.00549938282008343
# There are grounds to reject H0, accept H1.
# -------------------------------------
# 3b
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 7.605886262000802
# p-value: 0.054899298343375445
# No reason to reject H0, accept H0.
# ##############################################################
# Stres
# -------------------------------------
# 1a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.8490243902438834
# p-value: 0.7635019008862484
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.194715447154479
# p-value: 0.38029488168101827
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.115365853658531
# p-value: 0.7145499536764821
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 8.657560975609755
# p-value: 0.07025259181088446
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.4688617886179003
# p-value: 0.8321425243500854
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.7912499609094232
# p-value: 0.4349935785241448
# No reason to reject H0, accept H0.
# ##############################################################
# Zmęcz
# -------------------------------------
# 1a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.7366666666666504
# p-value: 0.946731380548533
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 4.17865853658536
# p-value: 0.382366668249845
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.7421544715447084
# p-value: 0.7830467262425359
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 3.9497154471544746
# p-value: 0.4128538966567924
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 4.4593495934959435
# p-value: 0.3473948162996979
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 5.929997341839455
# p-value: 0.2044374637424948
# No reason to reject H0, accept H0.
# ##############################################################
# Czyt_map
# -------------------------------------
# 1a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 2.2261463414634335
# p-value: 0.328547724768423
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.6636097560975713
# p-value: 0.43526298034312005
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.5611707317073353
# p-value: 0.4581377546009068
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 4.307560975609775
# p-value: 0.11604462218852103
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 1.6862926829268332
# p-value: 0.4303543493212181
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 1.034109203490003
# p-value: 0.5962742291316434
# No reason to reject H0, accept H0.
# ##############################################################
# Podziel_uwg
# -------------------------------------
# 1a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 5.366027874564452
# p-value: 0.2517591215151027
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 6.552555168408844
# p-value: 0.16150895703243717
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.3498112659698194
# p-value: 0.5010789874977928
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.4698461091753785
# p-value: 0.8319690893179891
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.402380952380966
# p-value: 0.4928758889187793
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.4407741166642047
# p-value: 0.6552715644576842
# No reason to reject H0, accept H0.
# ##############################################################
# Analit_myśl
# -------------------------------------
# 1a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.498619053176185
# p-value: 0.32094126914836596
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.383592017738366
# p-value: 0.22291161912799376
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.550737153304553
# p-value: 0.4661914828353364
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.7901116427432413
# p-value: 0.6170891137862051
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.292410627455567
# p-value: 0.5139763882842943
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.697232894516133
# p-value: 0.2960680820749757
# No reason to reject H0, accept H0.
# ##############################################################
# Spostrzeg
# -------------------------------------
# 1a
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 1.2913460284335514
# p-value: 0.7311890664243681
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.3976685796269805
# p-value: 0.7060813200415011
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.27395004565018155
# p-value: 0.9648509290882381
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 1.4449214164601756
# p-value: 0.6950395000034777
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 4.901705360636498
# p-value: 0.17913788982234763
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 3.7754100060053246
# p-value: 0.2867593447455348
# No reason to reject H0, accept H0.
# ##############################################################
# Czyt_ze_zroz
# -------------------------------------
# 1a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 7.2170757327320985
# p-value: 0.12485187737656384
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 9.484702295552381
# p-value: 0.05006253206349229
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.5489649518343924
# p-value: 0.9685624849738713
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.233019061283059
# p-value: 0.6929889350538472
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.5436897929903637
# p-value: 0.636829916992133
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.5827150449259395
# p-value: 0.9649649356478222
# No reason to reject H0, accept H0.
# ##############################################################
# Wzrokowiec
# -------------------------------------
# 1a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.2412543554006845
# p-value: 0.23656386176197639
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.1837746806039462
# p-value: 0.9801651152857104
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.5643670150987248
# p-value: 0.6674960717238521
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.44436701509873444
# p-value: 0.93093223849132
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 7.614947735191663
# p-value: 0.05467736001210984
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.4083077569145703
# p-value: 0.9385210100977848
# No reason to reject H0, accept H0.
# ##############################################################
# Słuchowiec
# -------------------------------------
# 1a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 2.2414982578397513
# p-value: 0.6914394189015943
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 4.195688153310101
# p-value: 0.3801696546646383
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 4.482630662020895
# p-value: 0.34461200526720026
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 0.6292770034843471
# p-value: 0.9597554394731496
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 3.4208275261324275
# p-value: 0.49001834013508705
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 2.0537989358422895
# p-value: 0.7258642985922005
# No reason to reject H0, accept H0.
# ##############################################################
# Kinestetyk
# -------------------------------------
# 1a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.252391200382604
# p-value: 0.3729246844424629
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.980310856049755
# p-value: 0.2893236973739637
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.796398852223817
# p-value: 0.5924544956882907
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 9.20962219033953
# p-value: 0.05606824092775343
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 7.292276422764218
# p-value: 0.1212256215200233
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 5.950470926713887
# p-value: 0.2028777940557326
# No reason to reject H0, accept H0.
# ##############################################################
# MAT
# -------------------------------------
# 1a
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 180.0
# p-value: 0.6342444138110057
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: -0.43152126510383493
# p-value: 0.6685278460139673
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 216.0
# p-value: 0.6342444138110057
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: 0.5843331754340001
# p-value: 0.5624494327299411
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: -0.6359619084508374
# p-value: 0.5286132026221775
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: 0.570209886384542
# p-value: 0.5718916387834532
# No reason to reject H0, accept H0.
# ##############################################################
# POL
# -------------------------------------
# 1a
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 116.0
# p-value: 0.4563047421112868
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 159.0
# p-value: 0.5382974190957754
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 168.0
# p-value: 0.364464957370777
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Conducting normality test...
# Conducting homogeneity variance test...
# Mann-Whitney test conducted...
# U-statistic: 129.0
# p-value: 0.7460218495237991
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Conducting normality test...
# Conducting homogeneity variance test...
# Mann-Whitney test conducted...
# U-statistic: 193.0
# p-value: 0.08604985828524142
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Conducting normality test...
# Conducting homogeneity variance test...
# Mann-Whitney test conducted...
# U-statistic: 161.0
# p-value: 0.4963781978442332
# No reason to reject H0, accept H0.
# ##############################################################
# HIST
# -------------------------------------
# 1a
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 83.0
# p-value: 0.6479264689791006
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 102.0
# p-value: 0.19120253857095962
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 57.0
# p-value: 0.5276944961155488
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Conducting normality test...
# Conducting homogeneity variance test...
# Mann-Whitney test conducted...
# U-statistic: 71.0
# p-value: 0.9826239194660248
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Conducting normality test...
# Conducting homogeneity variance test...
# Mann-Whitney test conducted...
# U-statistic: 95.0
# p-value: 0.3237772185140606
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Conducting normality test...
# Conducting homogeneity variance test...
# Mann-Whitney test conducted...
# U-statistic: 97.0
# p-value: 0.269334202152569
# No reason to reject H0, accept H0.
# ##############################################################
# Typ_uczenia
# -------------------------------------
# 1a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.22124168514415032
# p-value: 0.9740894384661328
# No reason to reject H0, accept H0.
# -------------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 5.259866962305978
# p-value: 0.15372786437130245
# No reason to reject H0, accept H0.
# -------------------------------------
# 2a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.487627494456774
# p-value: 0.4775312224168389
# No reason to reject H0, accept H0.
# -------------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.6702439024390259
# p-value: 0.6435693921041559
# No reason to reject H0, accept H0.
# -------------------------------------
# 3a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.0170288248337016
# p-value: 0.7971315785487555
# No reason to reject H0, accept H0.
# -------------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 7.145792288207159
# p-value: 0.06739323281824038
# No reason to reject H0, accept H0.

# %%
posthocNemenyi_test(df_merge, 'Duration_1b', 'JP_podst')
print()
posthocNemenyi_test(df_merge, 'Duration_1b', 'JP_roz')
print()
posthocNemenyi_test(df_merge, 'Duration_3b', 'JP_roz')
# Out:
# +----+----------+----------+---------+----------+
# |    |        4 |        2 |       3 |        1 |
# +====+==========+==========+=========+==========+
# |  4 | 1        | 0.353282 | 0.09182 | 1        |
# +----+----------+----------+---------+----------+
# |  2 | 0.353282 | 1        | 0.83523 | 0.353282 |
# +----+----------+----------+---------+----------+
# |  3 | 0.09182  | 0.83523  | 1       | 0.09182  |
# +----+----------+----------+---------+----------+
# |  1 | 1        | 0.353282 | 0.09182 | 1        |
# +----+----------+----------+---------+----------+
#
# +----+----------+----------+----------+----------+
# |    |        4 |        3 |        0 |        2 |
# +====+==========+==========+==========+==========+
# |  4 | 1        | 0.992107 | 0.073875 | 0.996057 |
# +----+----------+----------+----------+----------+
# |  3 | 0.992107 | 1        | 0.045699 | 0.97431  |
# +----+----------+----------+----------+----------+
# |  0 | 0.073875 | 0.045699 | 1        | 0.331673 |
# +----+----------+----------+----------+----------+
# |  2 | 0.996057 | 0.97431  | 0.331673 | 1        |
# +----+----------+----------+----------+----------+
#
# +----+----------+----------+----------+----------+
# |    |        4 |        3 |        0 |        2 |
# +====+==========+==========+==========+==========+
# |  4 | 1        | 0.992106 | 0.073853 | 0.996056 |
# +----+----------+----------+----------+----------+
# |  3 | 0.992106 | 1        | 0.045684 | 0.974307 |
# +----+----------+----------+----------+----------+
# |  0 | 0.073853 | 0.045684 | 1        | 0.33163  |
# +----+----------+----------+----------+----------+
# |  2 | 0.996056 | 0.974307 | 0.33163  | 1        |
# +----+----------+----------+----------+----------+

# %%
posthocNemenyi_test(df_merge, 'Duration_2b', 'Samopocz')
print()
posthocNemenyi_test(df_merge, 'Duration_3a', 'Samopocz')
# Out:
# +----+----------+----------+----------+----------+
# |    |        4 |        3 |        5 |        2 |
# +====+==========+==========+==========+==========+
# |  4 | 1        | 0.066631 | 0.219529 | 0.04679  |
# +----+----------+----------+----------+----------+
# |  3 | 0.066631 | 1        | 0.90017  | 0.994794 |
# +----+----------+----------+----------+----------+
# |  5 | 0.219529 | 0.90017  | 1        | 0.793153 |
# +----+----------+----------+----------+----------+
# |  2 | 0.04679  | 0.994794 | 0.793153 | 1        |
# +----+----------+----------+----------+----------+
#
# +----+----------+----------+----------+----------+
# |    |        4 |        3 |        5 |        2 |
# +====+==========+==========+==========+==========+
# |  4 | 1        | 0.066631 | 0.219529 | 0.04679  |
# +----+----------+----------+----------+----------+
# |  3 | 0.066631 | 1        | 0.90017  | 0.994794 |
# +----+----------+----------+----------+----------+
# |  5 | 0.219529 | 0.90017  | 1        | 0.793153 |
# +----+----------+----------+----------+----------+
# |  2 | 0.04679  | 0.994794 | 0.793153 | 1        |
# +----+----------+----------+----------+----------+

# %% [markdown]
# ### Summary:
# Significant statistically:
# - Well-being: 2b, 3a (2 vs 4)
# - JP_roz: 1b, 3b (0 vs 3)
# - JP_podst: 1b (poorly differentiated)

# %%
import csv
with open('./results/czas.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    row = []
    for item in results:
        if item != '\n':
            row.append(item)
        else:
            writer.writerow(row)
            row = []
    if row:
        writer.writerow(row)
