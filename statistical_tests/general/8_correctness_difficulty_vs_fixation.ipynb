# %% [markdown]
# # Correctness, difficulty and fixation
#
# ### Is there a statistically significant correlation between the correctness of the answer / the difficulty of the task and the total / average length of fixation?
#
# ### Is there a statistically significant correlation between the correctness of the answer / the difficulty of the task and the average pupil size?
#
# ### Is there a statistically significant correlation between the correctness of the answer / the difficulty of the task and the number of fixations?
#
# ### Is there a statistically significant difference in the correctness of the answer / the difficulty of the task depending on the last visited AOI?

# %%
import pandas as pd

from functions.tests.independent_groups.more_than_two_groups import chi2_or_chi2_yate_test, kruskal_wallis_test
from functions.tests.independent_groups.two_groups import chi2_or_fisher_test, mann_whitney_test
from functions.tests.correlations import correlation_independent_groups_test, spearman_corr

# %%
names_sum = {1: 'Zsumowane_wszystkie_grafiki_z_poleceniem',
             2: 'Zsumowane_wszystkie_grafiki_bez_polecenia',
             3: 'Zsumowane_wszystkie_grafiki_tylko_polecenie',
             4: 'Zsumowane_grafiki_A_z_poleceniem',
             5: 'Zsumowane_grafiki_A_bez_polecenia',
             6: 'Zsumowane_grafiki_A_tylko_polecenie',
             7: 'Zsumowane_grafiki_B_z_poleceniem',
             8: 'Zsumowane_grafiki_B_bez_polecenia',
             9: 'Zsumowane_grafiki_B_tylko_polecenie',
             10: 'Zsumowane_grafiki_1_z_poleceniem',
             11: 'Zsumowane_grafiki_1_bez_polecenia',
             12: 'Zsumowane_grafiki_1_tylko_polecenie',
             13: 'Zsumowane_grafiki_2_z_poleceniem',
             14: 'Zsumowane_grafiki_2_bez_polecenia',
             15: 'Zsumowane_grafiki_2_tylko_polecenie',
             16: 'Zsumowane_grafiki_3_z_poleceniem',
             17: 'Zsumowane_grafiki_3_bez_polecenia',
             18: 'Zsumowane_grafiki_3_tylko_polecenie',
             }

names_samples = {
    1: '1a',
    2: '1b',
    3: '2a',
    4: '2b',
    5: '3a',
    6: '3b',
}

path = '/Users/martasolarz/Studies/Thesis/Master_thesis/prepare_datasets/sets/fixation'

dfs_sum = [pd.read_csv(f'{path}/dfs_sum_{name}.csv') for _, name in names_sum.items()]

dfs_samples = [pd.read_csv(f'{path}/dfs_samples_{name}.csv') for _, name in names_samples.items()]

# %%
def print_nans(df):
    for col in df.filter(regex='Avg_pupil').columns:
        print(f"{col}: {df[col].isna().sum()} - for so many people there was no fixation on this element")

# %%
# Check NaNs
for df, id in zip(dfs_samples,['1a', '1b', '2a', '2b', '3a', '3b']):
    print(id)
    print_nans(df)
# Out:
# 1a
# Avg_pupil_map: 0 - for so many people there was no fixation on this element
# Avg_pupil_com: 3 - for so many people there was no fixation on this element
# 1b
# Avg_pupil_map: 1 - for so many people there was no fixation on this element
# Avg_pupil_com: 3 - for so many people there was no fixation on this element
# Avg_pupil_plt: 5 - for so many people there was no fixation on this element
# Avg_pupil_tab: 1 - for so many people there was no fixation on this element
# Avg_pupil_txt: 12 - for so many people there was no fixation on this element
# 2a
# Avg_pupil_map: 0 - for so many people there was no fixation on this element
# Avg_pupil_com: 1 - for so many people there was no fixation on this element
# 2b
# Avg_pupil_map: 0 - for so many people there was no fixation on this element
# Avg_pupil_com: 1 - for so many people there was no fixation on this element
# Avg_pupil_plt: 5 - for so many people there was no fixation on this element
# Avg_pupil_tab: 1 - for so many people there was no fixation on this element
# Avg_pupil_txt: 1 - for so many people there was no fixation on this element
# 3a
# Avg_pupil_map: 0 - for so many people there was no fixation on this element
# Avg_pupil_com: 4 - for so many people there was no fixation on this element
# 3b
# Avg_pupil_map: 0 - for so many people there was no fixation on this element
# Avg_pupil_com: 1 - for so many people there was no fixation on this element
# Avg_pupil_plt: 0 - for so many people there was no fixation on this element
# Avg_pupil_tab: 0 - for so many people there was no fixation on this element
# Avg_pupil_txt: 7 - for so many people there was no fixation on this element

# %%
names_sum = {
    1: 'Zsumowane wszystkie grafiki: z poleceniem:',
    2: 'Zsumowane wszystkie grafiki: bez polecenia:',
    3: 'Zsumowane wszystkie grafiki: tylko polecenie :',
    4: 'Zsumowane grafiki A: z poleceniem:',
    5: 'Zsumowane grafiki A: bez polecenia:',
    6: 'Zsumowane grafiki A: tylko polecenie :',
    7: 'Zsumowane grafiki B: z poleceniem:',
    8: 'Zsumowane grafiki B: bez polecenia:',
    9: 'Zsumowane grafiki B: tylko polecenie :',
    10: 'Zsumowane grafiki 1: z poleceniem:',
    11: 'Zsumowane grafiki 1: bez polecenia:',
    12: 'Zsumowane grafiki 1: tylko polecenie :',
    13: 'Zsumowane grafiki 2: z poleceniem:',
    14: 'Zsumowane grafiki 2: bez polecenia:',
    15: 'Zsumowane grafiki 2: tylko polecenie :',
    16: 'Zsumowane grafiki 3: z poleceniem:',
    17: 'Zsumowane grafiki 3: bez polecenia:',
    18: 'Zsumowane grafiki 3: tylko polecenie :',
}

cols_continue = {
    'Total': 'Całkowity czas fiksacji',
    'Avg': 'Średni czas fiksacji',
    'Avg_pupil': 'Średnia wielkość źrenicy',
}

names_samples = {
    1: '1a',
    2: '1b',
    3: '2a',
    4: '2b',
    5: '3a',
    6: '3b',
}

# %% [markdown]
# ### 1. Correctness
#
# ##### H0: There is no statistically significant correlation between the correctness of the answer and the given fixation metric.
#
# ##### H1: There is a statistically significant correlation between the correctness of the answer and the given fixation metric.
#
# ##### Significance level: $\alpha=0.05$

# %%
ALPHA = 0.05

# %% [markdown]
# Correctness vs total, average fixation time, average pupil size

# %%
param_category = 'Corr'
for col in cols_continue:
    print('##########################################')
    print(col)
    for i, df in enumerate(dfs_sum):
        print('------------------------------')
        print(names_sum[i+1])
        df = df.dropna()
        correlation_independent_groups_test(df[col], df[param_category], ALPHA)
# Out:
# ##########################################
# Total
# ------------------------------
# Zsumowane wszystkie grafiki: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.004054143198923145
# P-value: 0.9801924278624323
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.02316653256527511
# P-value: 0.8871662255677996
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.03581159825715445
# P-value: 0.826353566119123
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.222432518078884
# P-value: 0.16773115731662186
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.1454482125878597
# P-value: 0.3705195525930399
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.19685545514017128
# P-value: 0.22968893381739505
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.16055917655805987
# P-value: 0.3223182433558398
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.11388859919198718
# P-value: 0.48409214334192263
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.2712469175678606
# P-value: 0.09045117153923583
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.09222476486173675
# P-value: 0.5713983297539076
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.12185764012878657
# P-value: 0.45382416315208274
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.12702837676924617
# P-value: 0.4409372939230679
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.5981436973286031
# P-value: 4.5780284342437635e-05
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 2: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.6255695000445434
# P-value: 1.5867839785812646e-05
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 2: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.0892426913772661
# P-value: 0.5839547539473655
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.43057766221902555
# P-value: 0.005546676730170588
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 3: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.4697210860571188
# P-value: 0.0022281539834471237
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 3: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.04646766902382153
# P-value: 0.7787865407039365
# No reason to reject H0, accept H0.
# ##########################################
# Avg
# ------------------------------
# Zsumowane wszystkie grafiki: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.07780093853171559
# P-value: 0.633235631336941
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.07273667127683224
# P-value: 0.6555746477296527
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.09353926273025938
# P-value: 0.5659029071372017
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.20365662726656816
# P-value: 0.20750593730956104
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.15690501128466972
# P-value: 0.33359734528027296
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.21017339054178305
# P-value: 0.19906190268459964
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.028084949211441987
# P-value: 0.8634169838686557
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.022871720786731706
# P-value: 0.8885930693705718
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.04956399989901227
# P-value: 0.7613436328012818
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.015421190189995325
# P-value: 0.9247557173680051
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.009676040903526478
# P-value: 0.9527470675494587
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.13324934206286054
# P-value: 0.41869731878381766
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.20591118547047255
# P-value: 0.20241103504665497
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.2280041932138689
# P-value: 0.15706399528855738
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.055566836533309724
# P-value: 0.7334387546801331
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.055919176911561765
# P-value: 0.7318109250424234
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.03914342383809323
# P-value: 0.8104804301836406
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.12924474536399616
# P-value: 0.43294033468586424
# No reason to reject H0, accept H0.
# ##########################################
# Avg_pupil
# ------------------------------
# Zsumowane wszystkie grafiki: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.024324859193538873
# P-value: 0.8815635421907417
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.031081764525077445
# P-value: 0.8490029749933297
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.014672137291340906
# P-value: 0.9284008812746396
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.08199630454642952
# P-value: 0.614968436858484
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.08510374396078077
# P-value: 0.6015836338852282
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.007783411735360973
# P-value: 0.9624920433159591
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.016417304869923807
# P-value: 0.9199106216893848
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.004233393079665888
# P-value: 0.9793168402419273
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.0003097604692438455
# P-value: 0.9984864361995722
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.015421190189995325
# P-value: 0.9247557173680051
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.009676040903526478
# P-value: 0.9527470675494587
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.05019799895201469
# P-value: 0.7615253502067649
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.20591118547047255
# P-value: 0.20241103504665497
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.2280041932138689
# P-value: 0.15706399528855738
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.1629223280387407
# P-value: 0.31515280739647633
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.055919176911561765
# P-value: 0.7318109250424234
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.03914342383809323
# P-value: 0.8104804301836406
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.034850751767866145
# P-value: 0.8331794228227822
# No reason to reject H0, accept H0.

# %% [markdown]
# Correctness vs number of fixations

# %%
param_category = 'Corr'
col = 'Num'
for i, df in enumerate(dfs_sum):
    print('------------------------------')
    print(names_sum[i+1])
    df = df.dropna()
    correlation_independent_groups_test(df[col], df[param_category], ALPHA)
# Out:
# ------------------------------
# Zsumowane wszystkie grafiki: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.10666257701928751
# P-value: 0.5124196021034815
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.10782090364755127
# P-value: 0.5078236090260028
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.041802168356661236
# P-value: 0.7978670456976861
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.14240425253859712
# P-value: 0.38072372906545104
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.09027457191904732
# P-value: 0.5795959446356895
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.18941552480926124
# P-value: 0.24812921236379915
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.21941366571439053
# P-value: 0.17372433326348224
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.18967666066698136
# P-value: 0.24109296395035204
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.3222994964060845
# P-value: 0.04253532240556234
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 1: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.11550773828584733
# P-value: 0.4778586154732819
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.12448624161293408
# P-value: 0.4440700030176208
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.12954131494080903
# P-value: 0.43187641172407676
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.5492778821720269
# P-value: 0.00024197140512236215
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 2: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.5883763658249617
# P-value: 6.524674433638751e-05
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 2: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.1165000185592105
# P-value: 0.47405936312317265
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: z poleceniem:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.4445783095771405
# P-value: 0.004051396302264223
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 3: bez polecenia:
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.48234815140422177
# P-value: 0.001621886593923092
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 3: tylko polecenie :
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.0014532918883649081
# P-value: 0.9929942544894426
# No reason to reject H0, accept H0.

# %% [markdown]
# ### Summary:
#
# Statistically significant:
# - total fixation time:
#     - graphics: 2 (with command, without command), 3 (with command, without command)
# - number of fixations:
#     - sum: B (only command), 2 (with command, without command), 3 (with command, without command)
#
# Note: I used dropna()!

# %% [markdown]
# Each graphic separately:

# %%
columns_sample = ['Total_map', 'Avg_map', 'Num_map', 'Last_AOI', 'Avg_pupil_map', 'Total_com', 'Avg_com', 'Num_com', 'Avg_pupil_com', 'Total_plt','Avg_plt', 'Num_plt', 'Avg_pupil_plt', 'Total_tab', 'Avg_tab', 'Num_tab', 'Avg_pupil_tab', 'Total_txt', 'Avg_txt', 'Num_txt', 'Avg_pupil_txt']

param_category = 'Corr'
for col in columns_sample:
    print('##########################################')
    print(col)
    for i, df in enumerate(dfs_samples):
        if col not in df.columns:
            continue
        print('------------------------------')
        print(names_samples[i + 1])
        df = df.dropna()
        if col.startswith('Last_AOI'):
            if names_samples[i+1] in ['1a', '2a', '3a']:
                chi2_or_fisher_test(df, col, param_category, ALPHA)
            else:
                chi2_or_chi2_yate_test(df, col, param_category, ALPHA)
        else:
            correlation_independent_groups_test(df[col], df[param_category], ALPHA, biserial=True)
# Out:
# ##########################################
# Total_map
# ------------------------------
# 1a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.2369395511036369
# P-value: 0.15795638506512769
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.09304842103984708
# P-value: 0.6728226475575178
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.6861374500709487
# P-value: 1.4253896122565885e-06
# There are grounds to reject H0, accept H1.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.05263613559678152
# P-value: 0.7675022292932091
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.32287320150037885
# P-value: 0.0547739774817231
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.19630475588928234
# P-value: 0.2815666175535908
# No reason to reject H0, accept H0.
# ##########################################
# Avg_map
# ------------------------------
# 1a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.04073605922486693
# P-value: 0.8108091329710994
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.2560730056595499
# P-value: 0.23824318592491467
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.2764854506682833
# P-value: 0.08840587336296524
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.2270280246573664
# P-value: 0.19663035306392343
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.11032921081010896
# P-value: 0.5218000182068362
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.18957037486389042
# P-value: 0.2987270377158834
# No reason to reject H0, accept H0.
# ##########################################
# Num_map
# ------------------------------
# 1a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.2851355051297168
# P-value: 0.08715557879853
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.10475713867890676
# P-value: 0.634293005864756
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.676333427039934
# P-value: 2.2900821250855204e-06
# There are grounds to reject H0, accept H1.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.009873047362399487
# P-value: 0.9558061066489887
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.3202238069854382
# P-value: 0.05690837353228629
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.182867074599221
# P-value: 0.31645194223778417
# No reason to reject H0, accept H0.
# ##########################################
# Last_AOI
# ------------------------------
# 1a
# Corr      0   1
# Last_AOI
# 1a_com    1   6
# 1a_map    4  26
# Fisher test conducted...
# Fisher test statistic value: 1.0833333333333333
# P-value: 1.0
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Corr      0   1
# Last_AOI
# 1b_com    1   2
# 1b_map    1   0
# 1b_plt    0   2
# 1b_tab    0  16
# 1b_txt    0   1
# Chi2 test with Yate's correction conducted...
# Chi-squared test statistic value: 14.603174603174601
# P-value: 0.005599149521619991
# There are grounds to reject H0, accept H1.
# ------------------------------
# 2a
# Corr       0   1
# Last_AOI
# 2a_com     2   2
# 2a_map    10  25
# Fisher test conducted...
# Fisher test statistic value: 2.5
# P-value: 0.5732574679943101
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Corr      0   1
# Last_AOI
# 2b_com    1   1
# 2b_map    4   7
# 2b_plt    1   3
# 2b_tab    0   3
# 2b_txt    4  10
# Chi2 test with Yate's correction conducted...
# Chi-squared test statistic value: 1.9566558441558441
# P-value: 0.7437309633483931
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Corr       0   1
# Last_AOI
# 3a_com     0   4
# 3a_map    16  16
# Fisher test conducted...
# Fisher test statistic value: 0.0
# P-value: 0.11314828961887785
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Corr      0  1
# Last_AOI
# 3b_com    4  0
# 3b_map    3  3
# 3b_plt    7  9
# 3b_tab    2  3
# 3b_txt    0  1
# Chi2 test with Yate's correction conducted...
# Chi-squared test statistic value: 5.45
# P-value: 0.24415960512464058
# No reason to reject H0, accept H0.
# ##########################################
# Avg_pupil_map
# ------------------------------
# 1a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.14068285846778442
# P-value: 0.4062497561024332
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.32566947363946475
# P-value: 0.12940645904326128
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.2023858665676899
# P-value: 0.21660258886723063
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.190805991538333
# P-value: 0.2797262193067922
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.13991172065016416
# P-value: 0.41572600784755553
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.23015040345639995
# P-value: 0.20507585090741887
# No reason to reject H0, accept H0.
# ##########################################
# Total_com
# ------------------------------
# 1a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.2295487958451917
# P-value: 0.17172023214719914
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.11631052629980886
# P-value: 0.5971535274796473
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.19744962591969747
# P-value: 0.22825769376112232
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.0723746864455746
# P-value: 0.6841825181016095
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.09686196045011365
# P-value: 0.5741259563846353
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.040614777080541176
# P-value: 0.8253245892057532
# No reason to reject H0, accept H0.
# ##########################################
# Avg_com
# ------------------------------
# 1a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.12588906024625257
# P-value: 0.457825648555905
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.11633926978876855
# P-value: 0.5970622819384892
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.054301395243773906
# P-value: 0.7426687425288
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.013165069692142935
# P-value: 0.9410926355740235
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.00269147613517568
# P-value: 0.9875703072678637
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.030466667388839533
# P-value: 0.8685293839261405
# No reason to reject H0, accept H0.
# ##########################################
# Num_com
# ------------------------------
# 1a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.27797674978824166
# P-value: 0.09574409726520121
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.03492768848512194
# P-value: 0.8742883396167196
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.17544086947749382
# P-value: 0.2853878771774366
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.03624831604314917
# P-value: 0.8387262448033403
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.1373094978356424
# P-value: 0.4245370115526438
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.027153769332085225
# P-value: 0.8827211385125416
# No reason to reject H0, accept H0.
# ##########################################
# Avg_pupil_com
# ------------------------------
# 1a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.19991774624369368
# P-value: 0.2354895401766674
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.18609684207969415
# P-value: 0.39522434959591346
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.14315097879178065
# P-value: 0.3846384972289192
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.16448792373994223
# P-value: 0.35257860992400514
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.08071830037509471
# P-value: 0.6397970503263752
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.2369195329698235
# P-value: 0.1916963260468231
# No reason to reject H0, accept H0.
# ##########################################
# Total_plt
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.18609684207969415
# P-value: 0.39522434959591346
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.6251018661892511
# P-value: 7.737516149496154e-05
# There are grounds to reject H0, accept H1.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.1895356263758588
# P-value: 0.29881726460142327
# No reason to reject H0, accept H0.
# ##########################################
# Avg_plt
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.046535707915507415
# P-value: 0.8330079447872363
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.23035349467236546
# P-value: 0.18997691584510373
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.04400337458936601
# P-value: 0.811002606551436
# No reason to reject H0, accept H0.
# ##########################################
# Num_plt
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.23296661513614525
# P-value: 0.2847231598829734
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.5925187561295466
# P-value: 0.00022242741059739677
# There are grounds to reject H0, accept H1.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.2166319979784173
# P-value: 0.23369064025082026
# No reason to reject H0, accept H0.
# ##########################################
# Avg_pupil_plt
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.18609684207969415
# P-value: 0.39522434959591346
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.190805991538333
# P-value: 0.2797262193067922
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.27076518053694115
# P-value: 0.13389954384292124
# No reason to reject H0, accept H0.
# ##########################################
# Total_tab
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.34893157889942655
# P-value: 0.10270948101975805
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.36187343222787294
# P-value: 0.03546525907808041
# There are grounds to reject H0, accept H1.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.21661214442955293
# P-value: 0.2337345437058444
# No reason to reject H0, accept H0.
# ##########################################
# Avg_tab
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.0465472138392623
# P-value: 0.832967220230842
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.3652189961879373
# P-value: 0.033678088902179874
# There are grounds to reject H0, accept H1.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.25068763309486536
# P-value: 0.16638984516035266
# No reason to reject H0, accept H0.
# ##########################################
# Num_tab
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.32566947363946475
# P-value: 0.12940645904326128
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.296350060459938
# P-value: 0.08878602228872737
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.23707166220907328
# P-value: 0.19140281280003152
# No reason to reject H0, accept H0.
# ##########################################
# Avg_pupil_tab
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.2558831578595795
# P-value: 0.23860349986388105
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.16448792373994223
# P-value: 0.35257860992400514
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.2233812739429764
# P-value: 0.21908600701687472
# No reason to reject H0, accept H0.
# ##########################################
# Total_txt
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.046535707915507415
# P-value: 0.8330079447872363
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.00657951694959769
# P-value: 0.9705406818661828
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.4196860298322588
# P-value: 0.016791702224506166
# There are grounds to reject H0, accept H1.
# ##########################################
# Avg_txt
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.0930944276785246
# P-value: 0.6726696066813107
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.05264417963069366
# P-value: 0.7674676735567753
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.19972593066017025
# P-value: 0.27309715148670016
# No reason to reject H0, accept H0.
# ##########################################
# Num_txt
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.011697706772393273
# P-value: 0.9577531770819439
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.0
# P-value: 1.0
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.42080586389394026
# P-value: 0.016472149612782788
# There are grounds to reject H0, accept H1.
# ##########################################
# Avg_pupil_txt
# ------------------------------
# 1b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.16283473681973237
# P-value: 0.4578724290620052
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: -0.22370357628632145
# P-value: 0.20344246457355653
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting Spearman correlation test...
# Spearman correlation test statistic value: 0.2369195329698235
# P-value: 0.1916963260468231
# No reason to reject H0, accept H0.

# %% [markdown]
# ### Summary - each AOI (each graphic) separately - correctness:
#
# Significant statistically:
# - total fixation time: map: 2a; plot: 2b; table: 2b; text: 3b
# - average fixation time: table: 2b
# - number of fixations: map: 2a; plot: 2b; text: 3b
# - last AOI: 1b

# %% [markdown]
# ### 2. Difficulty
#
#
# ##### H0: There is no statistically significant correlation between the difficulty of the task and the given fixation metric.
#
# ##### H1: There is a statistically significant correlation between the difficulty of the task and the given fixation metric.
#
# ##### Significance level: $\alpha=0.05$
#
# Difficulty vs total, average fixation time, average pupil size

# %%
param_category = 'Diff'
for col in cols_continue:
    print('##########################################')
    print(col)
    for i, df in enumerate(dfs_sum):
        print('------------------------------')
        print(names_sum[i + 1])
        df = df.dropna()
        spearman_corr(df[col], df[param_category], ALPHA)
# Out:
# ##########################################
# Total
# ------------------------------
# Zsumowane wszystkie grafiki: z poleceniem:
# Spearman correlation test statistic value: 0.20597909619112528
# P-value: 0.20225893883271848
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: bez polecenia:
# Spearman correlation test statistic value: 0.20409370400630947
# P-value: 0.2065113107910015
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: tylko polecenie :
# Spearman correlation test statistic value: 0.14310126682751861
# P-value: 0.378372649560602
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: z poleceniem:
# Spearman correlation test statistic value: 0.3477292305344422
# P-value: 0.0279052671584421
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki A: bez polecenia:
# Spearman correlation test statistic value: 0.38284163819231337
# P-value: 0.01475980686500951
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki A: tylko polecenie :
# Spearman correlation test statistic value: -0.02236242309237021
# P-value: 0.8925119667595034
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: z poleceniem:
# Spearman correlation test statistic value: 0.2888577819990515
# P-value: 0.07065021878147636
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: bez polecenia:
# Spearman correlation test statistic value: 0.28467005797666
# P-value: 0.07501696292049209
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: tylko polecenie :
# Spearman correlation test statistic value: 0.23508359852970584
# P-value: 0.14423345328480927
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: z poleceniem:
# Spearman correlation test statistic value: 0.037014767689771716
# P-value: 0.8206133415301937
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: bez polecenia:
# Spearman correlation test statistic value: 0.021179053428793268
# P-value: 0.8967918929317825
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: tylko polecenie :
# Spearman correlation test statistic value: 0.13965350115716157
# P-value: 0.39647865460541043
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: z poleceniem:
# Spearman correlation test statistic value: 0.7040071637402009
# P-value: 4.012940073300468e-07
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 2: bez polecenia:
# Spearman correlation test statistic value: 0.6856167725241302
# P-value: 1.05133730449259e-06
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 2: tylko polecenie :
# Spearman correlation test statistic value: 0.3110083347842765
# P-value: 0.05077657399109976
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: z poleceniem:
# Spearman correlation test statistic value: 0.5115034303079911
# P-value: 0.000742685358145523
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 3: bez polecenia:
# Spearman correlation test statistic value: 0.5343570318475211
# P-value: 0.00038281756804736704
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 3: tylko polecenie :
# Spearman correlation test statistic value: 0.054112376277868364
# P-value: 0.7435342028428883
# No reason to reject H0, accept H0.
# ##########################################
# Avg
# ------------------------------
# Zsumowane wszystkie grafiki: z poleceniem:
# Spearman correlation test statistic value: 0.0843713002705067
# P-value: 0.6047271432011672
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: bez polecenia:
# Spearman correlation test statistic value: 0.08465808002062719
# P-value: 0.6034954964347571
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: tylko polecenie :
# Spearman correlation test statistic value: 0.0273394690489776
# P-value: 0.8670095518537804
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: z poleceniem:
# Spearman correlation test statistic value: -0.0679517934497129
# P-value: 0.6769569728728887
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: bez polecenia:
# Spearman correlation test statistic value: -0.06684251125699608
# P-value: 0.6819507175841082
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: tylko polecenie :
# Spearman correlation test statistic value: -0.13544221562437017
# P-value: 0.41101145539047
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: z poleceniem:
# Spearman correlation test statistic value: 0.08898913547581984
# P-value: 0.5850280477352869
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: bez polecenia:
# Spearman correlation test statistic value: 0.12739844394898572
# P-value: 0.4333989764478685
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: tylko polecenie :
# Spearman correlation test statistic value: 0.07447835815471149
# P-value: 0.6478572009955617
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: z poleceniem:
# Spearman correlation test statistic value: 0.027105302324006063
# P-value: 0.8681385803745679
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: bez polecenia:
# Spearman correlation test statistic value: 0.044592594145945456
# P-value: 0.7846832674512157
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: tylko polecenie :
# Spearman correlation test statistic value: -0.0025726946953949417
# P-value: 0.9875983822341043
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: z poleceniem:
# Spearman correlation test statistic value: -0.08495977608674261
# P-value: 0.6022009576955476
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: bez polecenia:
# Spearman correlation test statistic value: -0.07969169526963905
# P-value: 0.6249755764193007
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: tylko polecenie :
# Spearman correlation test statistic value: 0.135408732101858
# P-value: 0.4047936774352827
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: z poleceniem:
# Spearman correlation test statistic value: -0.24987236538034044
# P-value: 0.11994564719089186
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: bez polecenia:
# Spearman correlation test statistic value: -0.22882050006176904
# P-value: 0.15554359202928889
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: tylko polecenie :
# Spearman correlation test statistic value: 0.06495859736036026
# P-value: 0.694405769295442
# No reason to reject H0, accept H0.
# ##########################################
# Avg_pupil
# ------------------------------
# Zsumowane wszystkie grafiki: z poleceniem:
# Spearman correlation test statistic value: -0.17816956146509233
# P-value: 0.2713579323028115
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: bez polecenia:
# Spearman correlation test statistic value: -0.1642176592974555
# P-value: 0.31126813968124256
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: tylko polecenie :
# Spearman correlation test statistic value: -0.18184607622548316
# P-value: 0.2614287085666103
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: z poleceniem:
# Spearman correlation test statistic value: -0.05557847952475185
# P-value: 0.7333849450654921
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: bez polecenia:
# Spearman correlation test statistic value: -0.02696477715162481
# P-value: 0.868816242791847
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: tylko polecenie :
# Spearman correlation test statistic value: -0.07691001586908634
# P-value: 0.6416691207306702
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: z poleceniem:
# Spearman correlation test statistic value: -0.24212658893100067
# P-value: 0.13225118434143676
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: bez polecenia:
# Spearman correlation test statistic value: -0.2433638710285254
# P-value: 0.13022499922961142
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: tylko polecenie :
# Spearman correlation test statistic value: -0.229753767955753
# P-value: 0.15381851354199197
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: z poleceniem:
# Spearman correlation test statistic value: 0.027105302324006063
# P-value: 0.8681385803745679
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: bez polecenia:
# Spearman correlation test statistic value: 0.044592594145945456
# P-value: 0.7846832674512157
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: tylko polecenie :
# Spearman correlation test statistic value: 0.013335334321022194
# P-value: 0.9357814619427927
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: z poleceniem:
# Spearman correlation test statistic value: -0.08495977608674261
# P-value: 0.6022009576955476
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: bez polecenia:
# Spearman correlation test statistic value: -0.07969169526963905
# P-value: 0.6249755764193007
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: tylko polecenie :
# Spearman correlation test statistic value: -0.11062969715917442
# P-value: 0.4967657955278243
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: z poleceniem:
# Spearman correlation test statistic value: -0.24987236538034044
# P-value: 0.11994564719089186
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: bez polecenia:
# Spearman correlation test statistic value: -0.22882050006176904
# P-value: 0.15554359202928889
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 3: tylko polecenie :
# Spearman correlation test statistic value: -0.23608953582102116
# P-value: 0.1479096562212758
# No reason to reject H0, accept H0.

# %% [markdown]
# Difficulty vs number of fixations

# %%
param_category = 'Diff'
col = 'Num'
for i, df in enumerate(dfs_sum):
    print('------------------------------')
    print(names_sum[i + 1])
    df = df.dropna()
    spearman_corr(df[col], df[param_category], ALPHA)
# Out:
# ------------------------------
# Zsumowane wszystkie grafiki: z poleceniem:
# Spearman correlation test statistic value: 0.24642075855542403
# P-value: 0.12531824627990718
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: bez polecenia:
# Spearman correlation test statistic value: 0.22455020921156083
# P-value: 0.16361691752295346
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane wszystkie grafiki: tylko polecenie :
# Spearman correlation test statistic value: 0.17781750601383092
# P-value: 0.2723215673773639
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki A: z poleceniem:
# Spearman correlation test statistic value: 0.4718793707867644
# P-value: 0.0021122128248183625
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki A: bez polecenia:
# Spearman correlation test statistic value: 0.4776996528809582
# P-value: 0.0018255877784280027
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki A: tylko polecenie :
# Spearman correlation test statistic value: -0.00856964635894935
# P-value: 0.9587063057673306
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: z poleceniem:
# Spearman correlation test statistic value: 0.32378720736763533
# P-value: 0.04153549024092772
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki B: bez polecenia:
# Spearman correlation test statistic value: 0.29019023964253976
# P-value: 0.06930358297620852
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki B: tylko polecenie :
# Spearman correlation test statistic value: 0.2913733490813385
# P-value: 0.06812491696159743
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: z poleceniem:
# Spearman correlation test statistic value: 0.06295425055898182
# P-value: 0.6995594242390899
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: bez polecenia:
# Spearman correlation test statistic value: 0.017592697113396026
# P-value: 0.9141972028618081
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 1: tylko polecenie :
# Spearman correlation test statistic value: 0.21976876758211983
# P-value: 0.17884994158880185
# No reason to reject H0, accept H0.
# ------------------------------
# Zsumowane grafiki 2: z poleceniem:
# Spearman correlation test statistic value: 0.6772836265043483
# P-value: 1.5904620221036882e-06
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 2: bez polecenia:
# Spearman correlation test statistic value: 0.6880915215760682
# P-value: 9.27296813182279e-07
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 2: tylko polecenie :
# Spearman correlation test statistic value: 0.3390244170642275
# P-value: 0.03235348274750473
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 3: z poleceniem:
# Spearman correlation test statistic value: 0.5579005995014326
# P-value: 0.00018377807340759944
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 3: bez polecenia:
# Spearman correlation test statistic value: 0.5763725914111216
# P-value: 9.931567923600646e-05
# There are grounds to reject H0, accept H1.
# ------------------------------
# Zsumowane grafiki 3: tylko polecenie :
# Spearman correlation test statistic value: 0.13636317331131037
# P-value: 0.40780767684261243
# No reason to reject H0, accept H0.

# %% [markdown]
# ### Summary:
#
# Statistically significant:
# - total fixation time:
#     - sum: A (with command, without command), 2 (with command, without command), 3 (with command, without command)
# - number of fixations:
#     - sum: A (with command, without command), 2 (with command, without command), 3 (with command, without command)

# %% [markdown]
# Each graphic separately:

# %%
param_category = 'Diff'
for col in columns_sample:
    print('##########################################')
    print(col)
    for i, df in enumerate(dfs_samples):
        if col not in df.columns:
            continue
        print('------------------------------')
        print(names_samples[i+1])
        df = df.dropna()
        if col.startswith('Last_AOI'):
            data = [df[param_category][df['Last_AOI'] == category] for category in pd.unique(df['Last_AOI'])]
            if names_samples[i+1] in ['1a', '2a', '3a']:
                mann_whitney_test(data, print_flag=True, alpha=ALPHA)
            else:
                kruskal_wallis_test(data, print_flag=True, alpha=ALPHA)
        else:
            spearman_corr(df[col], df[param_category], ALPHA)
# Out:
# ##########################################
# Total_map
# ------------------------------
# 1a
# Spearman correlation test statistic value: 0.0002489608124386103
# P-value: 0.9988331816609712
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Spearman correlation test statistic value: 0.0036461775525404873
# P-value: 0.9868265048838907
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Spearman correlation test statistic value: 0.7214339250756516
# P-value: 2.1984196472154125e-07
# There are grounds to reject H0, accept H1.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.5303686756385861
# P-value: 0.0012531751409962297
# There are grounds to reject H0, accept H1.
# ------------------------------
# 3a
# Spearman correlation test statistic value: 0.6730722319511814
# P-value: 6.867748290374238e-06
# There are grounds to reject H0, accept H1.
# ------------------------------
# 3b
# Spearman correlation test statistic value: -0.20686534168941165
# P-value: 0.25596067986886556
# No reason to reject H0, accept H0.
# ##########################################
# Avg_map
# ------------------------------
# 1a
# Spearman correlation test statistic value: -0.24081648192477054
# P-value: 0.1510645448974473
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Spearman correlation test statistic value: 0.03127613800178736
# P-value: 0.8873449674234922
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Spearman correlation test statistic value: 0.3476579021552769
# P-value: 0.030110231807740025
# There are grounds to reject H0, accept H1.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.2684002591569166
# P-value: 0.12483107545718998
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Spearman correlation test statistic value: -0.035057580919052776
# P-value: 0.8391473347812677
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: -0.035086077959787264
# P-value: 0.8488086555817496
# No reason to reject H0, accept H0.
# ##########################################
# Num_map
# ------------------------------
# 1a
# Spearman correlation test statistic value: 0.17145017145025718
# P-value: 0.31028031908457204
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Spearman correlation test statistic value: -0.06255227600357471
# P-value: 0.7767641982263161
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Spearman correlation test statistic value: 0.7239327210280873
# P-value: 1.905463171222143e-07
# There are grounds to reject H0, accept H1.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.5023832840000645
# P-value: 0.002463973310048346
# There are grounds to reject H0, accept H1.
# ------------------------------
# 3a
# Spearman correlation test statistic value: 0.6875551421310806
# P-value: 3.6111186507472983e-06
# There are grounds to reject H0, accept H1.
# ------------------------------
# 3b
# Spearman correlation test statistic value: -0.19585024544268004
# P-value: 0.282704389372743
# No reason to reject H0, accept H0.
# ##########################################
# Last_AOI
# ------------------------------
# 1a
# U-statistic: 145.0
# p-value: 0.10772346648941881
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# H: 2.7357793336994267
# p-value: 0.602968366213839
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# U-statistic: 66.0
# p-value: 0.8659459703255783
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# H: 1.9416307344313382
# p-value: 0.7464937621937595
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# U-statistic: 68.5
# p-value: 0.8348273291852392
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# H: 4.922600262984898
# p-value: 0.29533178714599473
# No reason to reject H0, accept H0.
# ##########################################
# Avg_pupil_map
# ------------------------------
# 1a
# Spearman correlation test statistic value: 0.10456354122421635
# P-value: 0.5379625452183254
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Spearman correlation test statistic value: -0.200018882882221
# P-value: 0.36016145326814364
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Spearman correlation test statistic value: -0.07266013366132497
# P-value: 0.6602407018227798
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.020954404425110255
# P-value: 0.9063634843839464
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Spearman correlation test statistic value: -0.1668686008718573
# P-value: 0.33069259488058356
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: -0.2081962767921928
# P-value: 0.25284632729492784
# No reason to reject H0, accept H0.
# ##########################################
# Total_com
# ------------------------------
# 1a
# Spearman correlation test statistic value: -0.16619119271280466
# P-value: 0.32557623334157737
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Spearman correlation test statistic value: 0.18803858520958802
# P-value: 0.39022277825545904
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Spearman correlation test statistic value: 0.3648825289813996
# P-value: 0.022375503060805636
# There are grounds to reject H0, accept H1.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.14271219377404637
# P-value: 0.42072981086067507
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Spearman correlation test statistic value: -0.09183104313155724
# P-value: 0.5942629105776318
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: 0.1393679186197966
# P-value: 0.44681144762435554
# No reason to reject H0, accept H0.
# ##########################################
# Avg_com
# ------------------------------
# 1a
# Spearman correlation test statistic value: -0.09349586868981008
# P-value: 0.5820440000254102
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Spearman correlation test statistic value: -0.08075674091593472
# P-value: 0.7141436311851551
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Spearman correlation test statistic value: 0.28617307887651117
# P-value: 0.07737067437817173
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: -0.08337960830707812
# P-value: 0.6392018876634012
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Spearman correlation test statistic value: -0.09039403419060862
# P-value: 0.6000708187877454
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: -0.13026538429514514
# P-value: 0.477325248860208
# No reason to reject H0, accept H0.
# ##########################################
# Num_com
# ------------------------------
# 1a
# Spearman correlation test statistic value: -0.14231698111519211
# P-value: 0.4007641556403062
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Spearman correlation test statistic value: 0.3222239502208726
# P-value: 0.1337488592854867
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Spearman correlation test statistic value: 0.29071547175595563
# P-value: 0.07258189602348464
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.2412226629005712
# P-value: 0.16933594389947643
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Spearman correlation test statistic value: -0.10829439358092281
# P-value: 0.5295531969769725
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: 0.21346183918743378
# P-value: 0.24077138769158293
# No reason to reject H0, accept H0.
# ##########################################
# Avg_pupil_com
# ------------------------------
# 1a
# Spearman correlation test statistic value: 0.07369240048182867
# P-value: 0.6646817794960197
# No reason to reject H0, accept H0.
# ------------------------------
# 1b
# Spearman correlation test statistic value: -0.1552229872367236
# P-value: 0.47943349876222674
# No reason to reject H0, accept H0.
# ------------------------------
# 2a
# Spearman correlation test statistic value: -0.1163194882851109
# P-value: 0.48069818205462256
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: -0.0026986732971732903
# P-value: 0.9879147072763255
# No reason to reject H0, accept H0.
# ------------------------------
# 3a
# Spearman correlation test statistic value: -0.1668686008718573
# P-value: 0.33069259488058356
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: -0.17929597170323086
# P-value: 0.32615640383409594
# No reason to reject H0, accept H0.
# ##########################################
# Total_plt
# ------------------------------
# 1b
# Spearman correlation test statistic value: -0.1265744493239055
# P-value: 0.5649527847004512
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.32354802281929085
# P-value: 0.061959241637695
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: 0.2964182607479713
# P-value: 0.09948769514520975
# No reason to reject H0, accept H0.
# ##########################################
# Avg_plt
# ------------------------------
# 1b
# Spearman correlation test statistic value: -0.08231977461108184
# P-value: 0.7088430050762556
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.09773771884814592
# P-value: 0.5823834753095569
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: -0.1323451048898303
# P-value: 0.4702597306945253
# No reason to reject H0, accept H0.
# ##########################################
# Num_plt
# ------------------------------
# 1b
# Spearman correlation test statistic value: -0.07198856765351966
# P-value: 0.7441098079204237
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.30116556005909906
# P-value: 0.08348046172904455
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: 0.35434641230200975
# P-value: 0.0466095871544238
# There are grounds to reject H0, accept H1.
# ##########################################
# Avg_pupil_plt
# ------------------------------
# 1b
# Spearman correlation test statistic value: -0.17084946246189714
# P-value: 0.4357270636091872
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.047941137396843164
# P-value: 0.7877441388058006
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: -0.20572454017274205
# P-value: 0.2586501678252741
# No reason to reject H0, accept H0.
# ##########################################
# Total_tab
# ------------------------------
# 1b
# Spearman correlation test statistic value: 0.07500708108083289
# P-value: 0.7337506595572008
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.45909195149559745
# P-value: 0.0063118024510744235
# There are grounds to reject H0, accept H1.
# ------------------------------
# 3b
# Spearman correlation test statistic value: 0.3772250348453977
# P-value: 0.03330827884228944
# There are grounds to reject H0, accept H1.
# ##########################################
# Avg_tab
# ------------------------------
# 1b
# Spearman correlation test statistic value: -0.11569309141225777
# P-value: 0.5991149771081219
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.21822901875846312
# P-value: 0.21501365446406479
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: 0.1955415405416651
# P-value: 0.2834788513448323
# No reason to reject H0, accept H0.
# ##########################################
# Num_tab
# ------------------------------
# 1b
# Spearman correlation test statistic value: 0.12084474174134185
# P-value: 0.5828331295890531
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.45522333181139185
# P-value: 0.00682637714678824
# There are grounds to reject H0, accept H1.
# ------------------------------
# 3b
# Spearman correlation test statistic value: 0.43559036438903326
# P-value: 0.01270666434544577
# There are grounds to reject H0, accept H1.
# ##########################################
# Avg_pupil_tab
# ------------------------------
# 1b
# Spearman correlation test statistic value: -0.20262329541974997
# P-value: 0.353809780726449
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.016509530759177778
# P-value: 0.9261643990368285
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: -0.2150410858922101
# P-value: 0.23722632776399197
# No reason to reject H0, accept H0.
# ##########################################
# Total_txt
# ------------------------------
# 1b
# Spearman correlation test statistic value: -0.2865561774436393
# P-value: 0.1849591767865254
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.2841544236435406
# P-value: 0.1033790642498093
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: 0.2081962767921928
# P-value: 0.25284632729492784
# No reason to reject H0, accept H0.
# ##########################################
# Avg_txt
# ------------------------------
# 1b
# Spearman correlation test statistic value: -0.6337063025103848
# P-value: 0.0011680787463163186
# There are grounds to reject H0, accept H1.
# ------------------------------
# 2b
# Spearman correlation test statistic value: -0.03167456474522619
# P-value: 0.8588572883986914
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: 0.0696967348090083
# P-value: 0.7046584591041276
# No reason to reject H0, accept H0.
# ##########################################
# Num_txt
# ------------------------------
# 1b
# Spearman correlation test statistic value: -0.1613511998518002
# P-value: 0.46203467910681506
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: 0.29378840271819023
# P-value: 0.09171180509047833
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: 0.2027466111234222
# P-value: 0.2657580597813665
# No reason to reject H0, accept H0.
# ##########################################
# Avg_pupil_txt
# ------------------------------
# 1b
# Spearman correlation test statistic value: -0.16720328490935665
# P-value: 0.4457299805874191
# No reason to reject H0, accept H0.
# ------------------------------
# 2b
# Spearman correlation test statistic value: -0.03778142616042607
# P-value: 0.8320001455733588
# No reason to reject H0, accept H0.
# ------------------------------
# 3b
# Spearman correlation test statistic value: -0.2840595776507179
# P-value: 0.11511645325908985
# No reason to reject H0, accept H0.

# %% [markdown]
# ### Summary - each AOI (each graphic) separately - difficulty:
#
# Significant statistically:
#
# - total fixation time: map: 2a, 2b, 3a; command: 2a; table: 2b, 3b
# - average fixation time: map: 2a; text: 1b
# - number of fixations: map: 2a, 2b, 3a; plot: 3b; table: 2b, 3b
