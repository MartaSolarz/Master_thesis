# %% [markdown]
# # Temat testów
#
# Czy istnieje istotna statystycznie różnica w poprawności odpowiedzi/trudności zadania w zależności od:
# - liczby wizyt (na wszystkich elementach grafiki, tylko na treści, tylko na poleceniu)?
# - długości całkowitej i średniej wizyty (na wszystkich elementach grafiki, tylko na treści, tylko na poleceniu)?

# %%
import pandas as pd

from functions.tests.categorical_and_quntitative import conduct_categorical_vs_quantitative_for_many_groups_test, conduct_categorical_vs_quantitative_for_two_groups_test

# %%
names_sum = {1: 'Zsumowane_wszystkie_grafiki_z_poleceniem',
             2: 'Zsumowane_wszystkie_grafiki_bez_polecenia',
             3: 'Zsumowane_wszystkie_grafiki_tylko_polecenie',
             4: 'Zsumowane_grafiki_A_z_poleceniem',
             5: 'Zsumowane_grafiki_A_bez_polecenia',
             6: 'Zsumowane_grafiki_A_tylko_polecenie',
             7: 'Zsumowane_grafiki_B_z_poleceniem',
             8: 'Zsumowane_grafiki_B_bez_polecenia',
             9: 'Zsumowane_grafiki_B_tylko_polecenie',
             10: 'Zsumowane_grafiki_1_z_poleceniem',
             11: 'Zsumowane_grafiki_1_bez_polecenia',
             12: 'Zsumowane_grafiki_1_tylko_polecenie',
             13: 'Zsumowane_grafiki_2_z_poleceniem',
             14: 'Zsumowane_grafiki_2_bez_polecenia',
             15: 'Zsumowane_grafiki_2_tylko_polecenie',
             16: 'Zsumowane_grafiki_3_z_poleceniem',
             17: 'Zsumowane_grafiki_3_bez_polecenia',
             18: 'Zsumowane_grafiki_3_tylko_polecenie',
             }

names_coll = {1: 'Kolekcja_wszystkie_grafiki_z_poleceniem',
              2: 'Kolekcja_wszystkie_grafiki_bez_polecenia',
              3: 'Kolekcja_wszystkie_grafiki_tylko_polecenie',
              4: 'Kolekcja_grafiki_A_z_poleceniem',
              5: 'Kolekcja_grafiki_A_bez_polecenia',
              6: 'Kolekcja_grafiki_A_tylko_polecenie',
              7: 'Kolekcja_grafiki_B_z_poleceniem',
              8: 'Kolekcja_grafiki_B_bez_polecenia',
              9: 'Kolekcja_grafiki_B_tylko_polecenie',
              10: 'Kolekcja_grafiki_1_z_poleceniem',
              11: 'Kolekcja_grafiki_1_bez_polecenia',
              12: 'Kolekcja_grafiki_1_tylko_polecenie_',
              13: 'Kolekcja_grafiki_2_z_poleceniem',
              14: 'Kolekcja_grafiki_2_bez_polecenia',
              15: 'Kolekcja_grafiki_2_tylko_polecenie',
              16: 'Kolekcja_grafiki_3_z_poleceniem',
              17: 'Kolekcja_grafiki_3_bez_polecenia',
              18: 'Kolekcja_grafiki_3_tylko_polecenie',
              }

names_samples = {
    1: '1a',
    2: '1b',
    3: '2a',
    4: '2b',
    5: '3a',
    6: '3b',
}

path = '/Users/martasolarz/Studies/Thesis/Master_thesis/prepare_datasets/sets/visit'

dfs_sum = [pd.read_csv(f'{path}/dfs_sum_{name}.csv') for _, name in names_sum.items()]

dfs_coll = [pd.read_csv(f'{path}/dfs_coll_{name}.csv') for _, name in names_coll.items()]

dfs_samples = [pd.read_csv(f'{path}/dfs_samples_{name}.csv') for _, name in names_samples.items()]

# %%
def print_nans(df):
    for col in df.filter(regex='Avg').columns:
        print(f"{col}: {df[col].isna().sum()} - dla tylu osób nie odnotowano ani jednej wizyty na tym elemencie")

# %%
# Analiza NaNów
for df, id in zip(dfs_samples, ['1a', '1b', '2a', '2b', '3a', '3b']):
    print(id)
    print_nans(df)
# Out:
# 1a
# Avg_map: 0 - dla tylu osób nie odnotowano ani jednej wizyty na tym elemencie
# Avg_com: 3 - dla tylu osób nie odnotowano ani jednej wizyty na tym elemencie
# 1b
# Avg_map: 1 - dla tylu osób nie odnotowano ani jednej wizyty na tym elemencie
# Avg_com: 3 - dla tylu osób nie odnotowano ani jednej wizyty na tym elemencie
# Avg_plt: 5 - dla tylu osób nie odnotowano ani jednej wizyty na tym elemencie
# Avg_tab: 1 - dla tylu osób nie odnotowano ani jednej wizyty na tym elemencie
# Avg_txt: 12 - dla tylu osób nie odnotowano ani jednej wizyty na tym elemencie
# 2a
# Avg_map: 0 - dla tylu osób nie odnotowano ani jednej wizyty na tym elemencie
# Avg_com: 1 - dla tylu osób nie odnotowano ani jednej wizyty na tym elemencie
# 2b
# Avg_map: 0 - dla tylu osób nie odnotowano ani jednej wizyty na tym elemencie
# Avg_com: 1 - dla tylu osób nie odnotowano ani jednej wizyty na tym elemencie
# Avg_plt: 5 - dla tylu osób nie odnotowano ani jednej wizyty na tym elemencie
# Avg_tab: 1 - dla tylu osób nie odnotowano ani jednej wizyty na tym elemencie
# Avg_txt: 1 - dla tylu osób nie odnotowano ani jednej wizyty na tym elemencie
# 3a
# Avg_map: 0 - dla tylu osób nie odnotowano ani jednej wizyty na tym elemencie
# Avg_com: 3 - dla tylu osób nie odnotowano ani jednej wizyty na tym elemencie
# 3b
# Avg_map: 0 - dla tylu osób nie odnotowano ani jednej wizyty na tym elemencie
# Avg_com: 1 - dla tylu osób nie odnotowano ani jednej wizyty na tym elemencie
# Avg_plt: 0 - dla tylu osób nie odnotowano ani jednej wizyty na tym elemencie
# Avg_tab: 0 - dla tylu osób nie odnotowano ani jednej wizyty na tym elemencie
# Avg_txt: 7 - dla tylu osób nie odnotowano ani jednej wizyty na tym elemencie

# %%
names_sum = {
    1: 'Zsumowane wszystkie grafiki: z poleceniem:',
    2: 'Zsumowane wszystkie grafiki: bez polecenia:',
    3: 'Zsumowane wszystkie grafiki: tylko polecenie:',
    4: 'Zsumowane grafiki A: z poleceniem:',
    5: 'Zsumowane grafiki A: bez polecenia:',
    6: 'Zsumowane grafiki A: tylko polecenie:',
    7: 'Zsumowane grafiki B: z poleceniem:',
    8: 'Zsumowane grafiki B: bez polecenia:',
    9: 'Zsumowane grafiki B: tylko polecenie:',
    10: 'Zsumowane grafiki 1: z poleceniem:',
    11: 'Zsumowane grafiki 1: bez polecenia:',
    12: 'Zsumowane grafiki 1: tylko polecenie:',
    13: 'Zsumowane grafiki 2: z poleceniem:',
    14: 'Zsumowane grafiki 2: bez polecenia:',
    15: 'Zsumowane grafiki 2: tylko polecenie:',
    16: 'Zsumowane grafiki 3: z poleceniem:',
    17: 'Zsumowane grafiki 3: bez polecenia:',
    18: 'Zsumowane grafiki 3: tylko polecenie:',
}

cols_continue = {
    'Total': 'Całkowity czas wizyty',
    'Avg': 'Średni czas wizyty',
}

names_coll = {
    1: 'Kolekcja wszystkie grafiki: z poleceniem:',
    2: 'Kolekcja wszystkie grafiki: bez polecenia:',
    3: 'Kolekcja wszystkie grafiki: tylko polecenie:',
    4: 'Kolekcja grafiki A: z poleceniem:',
    5: 'Kolekcja grafiki A: bez polecenia:',
    6: 'Kolekcja grafiki A: tylko polecenie:',
    7: 'Kolekcja grafiki B: z poleceniem:',
    8: 'Kolekcja grafiki B: bez polecenia:',
    9: 'Kolekcja grafiki B: tylko polecenie:',
    10: 'Kolekcja grafiki 1: z poleceniem:',
    11: 'Kolekcja grafiki 1: bez polecenia:',
    12: 'Kolekcja grafiki 1: tylko polecenie :',
    13: 'Kolekcja grafiki 2: z poleceniem:',
    14: 'Kolekcja grafiki 2: bez polecenia:',
    15: 'Kolekcja grafiki 2: tylko polecenie:',
    16: 'Kolekcja grafiki 3: z poleceniem:',
    17: 'Kolekcja grafiki 3: bez polecenia:',
    18: 'Kolekcja grafiki 3: tylko polecenie:',
}

names_samples = {
    1: '1a',
    2: '1b',
    3: '2a',
    4: '2b',
    5: '3a',
    6: '3b',
}

# %% [markdown]
# ### Testy:
#
# **H0:** Nie ma istotnej statystycznie zależności między poprawnością odpowiedzi a daną metryką dotyczącą wizyt.
#
# **H1:** Istnieje istotna statystycznie zależność między poprawnością odpowiedzi a daną metryką dotyczącą wizyt.
#
# **Poziom istotności:** $\alpha=0.05$

# %%
ALPHA = 0.05

# %% [markdown]
# Poprawność vs całkowita, średnia długość wizyty

# %%
# kolekcje grafik
param_category = 'Corr'
for col in cols_continue:
    print('##########################################')
    print(col)
    for i, df in enumerate(dfs_coll):
        print('------------------------------')
        print(names_coll[i+1])
        df = df.dropna()
        conduct_categorical_vs_quantitative_for_many_groups_test(df, col, param_category, ALPHA)
# Out:
# ##########################################
# Total
# ------------------------------
# Kolekcja wszystkie grafiki: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.285941878282415
# p-value: 0.5928328840809698
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja wszystkie grafiki: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.13221952451772268
# p-value: 0.7161417692165353
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja wszystkie grafiki: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.895759695776472
# p-value: 0.16855371291578564
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki A: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 4.851745260087455
# p-value: 0.027618174215039686
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Kolekcja grafiki A: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 6.092298076255304
# p-value: 0.013577238185708879
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Kolekcja grafiki A: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.3550399812250764
# p-value: 0.5512738913615702
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki B: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.4600878919060278
# p-value: 0.2269161367483393
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki B: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.2598714416895973
# p-value: 0.26167542632293006
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki B: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.1395768664541097
# p-value: 0.2857417555122568
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 1: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.2017406712528658
# p-value: 0.6533194797798484
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 1: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.0539920783823176
# p-value: 0.30458946354432415
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 1: tylko polecenie :
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.280321991013746
# p-value: 0.257839175101681
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 2: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.8955239473183584
# p-value: 0.34398474748854246
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 2: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.4206848387793797
# p-value: 0.5165955207176065
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 2: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.4928781028507763
# p-value: 0.22177044236015028
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 3: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.023714821763587003
# p-value: 0.8776127519052832
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 3: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.2701266416510137
# p-value: 0.6032468326694003
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 3: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.1126441126441193
# p-value: 0.2915078985643383
# Brak podstaw do odrzucenia H0.
# ##########################################
# Avg
# ------------------------------
# Kolekcja wszystkie grafiki: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.8572101450407082
# p-value: 0.3545205921035085
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja wszystkie grafiki: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.5113820656985482
# p-value: 0.21892831648186536
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja wszystkie grafiki: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.12304174458442238
# p-value: 0.7257586042750337
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki A: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.3201566780911142
# p-value: 0.5715135023787706
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki A: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.8533955600929092
# p-value: 0.3555935217149653
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki A: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.9477501180597936
# p-value: 0.16282950336544355
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki B: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.17958808867899734
# p-value: 0.6717274698100797
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki B: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.00013118240489687962
# p-value: 0.9908616379459925
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki B: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.009903037123670707
# p-value: 0.9207301689823368
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 1: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.2608791953304326
# p-value: 0.26148473650930215
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 1: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.9891468626224444
# p-value: 0.3199509781416653
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 1: tylko polecenie :
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.1648829871213562
# p-value: 0.28045514898222546
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 2: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.3935511754343358
# p-value: 0.5304386347938863
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 2: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.03267345294470629
# p-value: 0.8565575346370778
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 2: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.00300198923024701
# p-value: 0.9563054391678922
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 3: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.05335834896808497
# p-value: 0.8173192599419673
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 3: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.16340994371484377
# p-value: 0.6860362729010161
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 3: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.4910968751759397
# p-value: 0.22204635144162793
# Brak podstaw do odrzucenia H0.

# %%
# sumy grafik
param_category = 'Corr'
for col in cols_continue:
    print('##########################################')
    print(col)
    for i, df in enumerate(dfs_sum):
        print('------------------------------')
        print(names_sum[i+1])
        df = df.dropna()
        conduct_categorical_vs_quantitative_for_many_groups_test(df, col, param_category, ALPHA)
# Out:
# ##########################################
# Total
# ------------------------------
# Zsumowane wszystkie grafiki: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.2563923880997265
# p-value: 0.8126498677411265
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane wszystkie grafiki: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.2691671133744364
# p-value: 0.8107845765498761
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane wszystkie grafiki: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 6.502884615384602
# p-value: 0.26031206706536225
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki A: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.53646341463417
# p-value: 0.46873735451642495
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki A: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.3507317073170668
# p-value: 0.7171230118238721
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki A: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.439939024390256
# p-value: 0.21771056312673115
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki B: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.1397212543553934
# p-value: 0.3705805361113301
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki B: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.395121951219508
# p-value: 0.4945433159231476
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki B: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.8713414634146233
# p-value: 0.4118900879917934
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 1: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.134038737446204
# p-value: 0.5672135761177934
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 1: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.36413199426112897
# p-value: 0.833546326934619
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 1: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.6623027259684449
# p-value: 0.718096467589796
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 2: z poleceniem:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 12.133797909407662
# p-value: 0.0023183513875890908
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Zsumowane grafiki 2: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 11.863254355400699
# p-value: 0.0026541596837003486
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Zsumowane grafiki 2: tylko polecenie:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 1.095554006968655
# p-value: 0.5782337944159421
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 3: z poleceniem:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 10.548780487804862
# p-value: 0.005121078365210571
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Zsumowane grafiki 3: bez polecenia:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 12.970731707317071
# p-value: 0.0015256025172718701
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Zsumowane grafiki 3: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.42789634146340916
# p-value: 0.8073902303831345
# Brak podstaw do odrzucenia H0.
# ##########################################
# Avg
# ------------------------------
# Zsumowane wszystkie grafiki: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.0250770570892485
# p-value: 0.6961195142034152
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane wszystkie grafiki: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.8147313052801053
# p-value: 0.8741402839761361
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane wszystkie grafiki: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.7498391852050474
# p-value: 0.5859649340985913
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki A: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.18826219512196474
# p-value: 0.9794615619651538
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki A: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.7386890243902542
# p-value: 0.8640683403575637
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki A: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.787674734965751
# p-value: 0.18802141886989743
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki B: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 5.619512195121956
# p-value: 0.13166266124056283
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki B: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.319599303135874
# p-value: 0.5087766026700633
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki B: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.120296167247389
# p-value: 0.5478176360075635
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 1: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.2163558106169319
# p-value: 0.5443418083270946
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 1: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.1656025824964047
# p-value: 0.9205340472191178
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 1: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.3357245337159185
# p-value: 0.8454702759431721
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 2: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 11.717639372822305
# p-value: 0.0028546110312161026
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Zsumowane grafiki 2: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 12.719163763066206
# p-value: 0.0017300899432030757
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Zsumowane grafiki 2: tylko polecenie:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 1.842459930313609
# p-value: 0.39802917786875647
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 3: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 5.635213414634137
# p-value: 0.05974876801869479
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 3: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 8.986585365853642
# p-value: 0.011183758546352661
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Zsumowane grafiki 3: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.4804878048780381
# p-value: 0.7864360240083532
# Brak podstaw do odrzucenia H0.

# %% [markdown]
# Poprawność vs liczba wizyt - dla sum stosujemy ANOVA/Kruskala-Wallisa (sumy, mamy więcej niż dwie grupy); dla kolekcji t-Student/Mann-Whitney (tylko dwie grupy: 0 vs 1)

# %%
# kolekcje grafik
param_category = 'Corr'
col = 'Num'
for i, df in enumerate(dfs_coll):
    print('------------------------------')
    print(names_coll[i+1])
    df = df.dropna()
    conduct_categorical_vs_quantitative_for_two_groups_test(df, col, param_category, ALPHA)
# Out:
# ------------------------------
# Kolekcja wszystkie grafiki: z poleceniem:
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 7908.5
# p-value: 9.98577235569631e-05
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Kolekcja wszystkie grafiki: bez polecenia:
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 7292.0
# p-value: 0.007949584706785884
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Kolekcja wszystkie grafiki: tylko polecenie:
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 6188.0
# p-value: 0.12183841151114791
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki A: z poleceniem:
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 1184.0
# p-value: 0.07900775461842052
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki A: bez polecenia:
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 1171.5
# p-value: 0.06452170984940477
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki A: tylko polecenie:
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 1186.0
# p-value: 0.47950486498657274
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki B: z poleceniem:
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 1869.0
# p-value: 0.04107105848925734
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Kolekcja grafiki B: bez polecenia:
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 1552.0
# p-value: 0.8198397830298274
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki B: tylko polecenie:
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 1800.5
# p-value: 0.021629517348105292
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Kolekcja grafiki 1: z poleceniem:
# Conducting normality test...
# Conducting homogeneity variance test...
# Mann-Whitney test conducted...
# U-statistic: 235.0
# p-value: 0.39880851181112087
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 1: bez polecenia:
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 172.0
# p-value: 0.06140410717435181
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 1: tylko polecenie :
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 267.5
# p-value: 0.9577008353961166
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 2: z poleceniem:
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 491.5
# p-value: 0.08178408327222025
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 2: bez polecenia:
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 453.5
# p-value: 0.03130734238708378
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Kolekcja grafiki 2: tylko polecenie:
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 537.0
# p-value: 0.29133190489749816
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 3: z poleceniem:
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 935.0
# p-value: 0.19493692498729875
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 3: bez polecenia:
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 912.0
# p-value: 0.28118150538693165
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 3: tylko polecenie:
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 778.5
# p-value: 0.5551009935632938
# Brak podstaw do odrzucenia H0.

# %%
# sumy grafik
param_category = 'Corr'
col = 'Num'
for i, df in enumerate(dfs_sum):
    print('------------------------------')
    print(names_sum[i+1])
    df = df.dropna()
    conduct_categorical_vs_quantitative_for_many_groups_test(df, col, param_category, ALPHA)
# Out:
# ------------------------------
# Zsumowane wszystkie grafiki: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.159759421107035
# p-value: 0.8266267716315115
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane wszystkie grafiki: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.2078361324731803
# p-value: 0.667978724409298
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane wszystkie grafiki: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 7.347677613986059
# p-value: 0.19604031754501652
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki A: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 5.948717676481699
# p-value: 0.11413205305142624
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki A: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.503312900296334
# p-value: 0.21199497450468546
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki A: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.9834780201658457
# p-value: 0.26325374098299975
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki B: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.3463035999838508
# p-value: 0.951097209897143
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki B: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.1339900084833645
# p-value: 0.545067017775968
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki B: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.7078745529832524
# p-value: 0.4388907548640576
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 1: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 5.767804918577604
# p-value: 0.055916126095444454
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 1: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.540715382538585
# p-value: 0.10327523282652236
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 1: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.740217251700372
# p-value: 0.25407935846740354
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 2: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 3.5880869553537997
# p-value: 0.1662864329856261
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 2: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 2.902420010827654
# p-value: 0.23428662842475795
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 2: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.006301774547228979
# p-value: 0.9968540715620797
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 3: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 3.719896088019553
# p-value: 0.15568071870377576
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 3: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.3267754942767916
# p-value: 0.8492618257213237
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 3: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.6986254376833492
# p-value: 0.7051725750350174
# Brak podstaw do odrzucenia H0.

# %% [markdown]
# Podsumowanie - poprawność:
#
# Istotne statystycznie:
#
# - całkowita długość wizyty:
#     - kolekcje: A (z poleceniem, bez polecenia)
#     - sumy: 2 (z poleceniem, bez polecenia), 3 (z poleceniem, bez polecenia)
# - średnia długość wizyty:
#     - sumy: 2 (z poleceniem, bez polecenia), 3 (bez polecenia)
# - liczba wizyt:
#     - kolekcje: wszystkie (z poleceniem, bez polecenia), B (z poleceniem, tylko polecenia), 2 (bez polecenia)
#
# Uwaga: stosujemy dropna()!

# %% [markdown]
# Test - poszczególne grafiki - poprawność

# %%
columns_sample = ['Total_map', 'Avg_map', 'Num_map', 'Total_com', 'Avg_com', 'Num_com', 'Total_plt', 'Avg_plt', 'Num_plt', 'Total_tab', 'Avg_tab', 'Num_tab',  'Total_txt', 'Avg_txt', 'Num_txt']

param_category = 'Corr'
for col in columns_sample:
    print('##########################################')
    print(col)
    for i, df in enumerate(dfs_samples):
        if col not in df.columns:
            continue
        print('------------------------------')
        print(names_samples[i + 1])
        df = df.dropna()
        if col.startswith('Total') or col.startswith('Avg'):
            conduct_categorical_vs_quantitative_for_many_groups_test(df, col, param_category, ALPHA)
        elif col.startswith('Num'):
            conduct_categorical_vs_quantitative_for_two_groups_test(df, col, param_category, ALPHA)
# Out:
# ##########################################
# Total_map
# ------------------------------
# 1a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 2.0210526315789537
# p-value: 0.1551315687271094
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.297619047619051
# p-value: 0.5853789284609594
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 17.889814814814827
# p-value: 2.340704616735994e-05
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# 2b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.005715158924224546
# p-value: 0.9397383945271541
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 6.398452012383913
# p-value: 0.011421991347094481
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 0.8181818181818272
# p-value: 0.36571229628151036
# Brak podstaw do odrzucenia H0.
# ##########################################
# Avg_map
# ------------------------------
# 1a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 2.2815789473684447
# p-value: 0.13091853136409953
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.1904761904761898
# p-value: 0.27523352407483126
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 18.670370370370392
# p-value: 1.5537831505308828e-05
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# 2b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.0014285714285762197
# p-value: 0.969849976993105
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 4.814860681114567
# p-value: 0.028215352453887194
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# 3b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.3196022727272805
# p-value: 0.5718467625452892
# Brak podstaw do odrzucenia H0.
# ##########################################
# Num_map
# ------------------------------
# 1a
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 96.5
# p-value: 0.4678696067154511
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 1b
# Data have not at least length 3...
# Mann-Whitney test conducted...
# U-statistic: 25.0
# p-value: 0.6984057703300718
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2a
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 221.0
# p-value: 0.07123235444859209
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting homogeneity variance test...
# Mann-Whitney test conducted...
# U-statistic: 130.0
# p-value: 0.7179728856480164
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3a
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 162.5
# p-value: 0.8276217714155035
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting homogeneity variance test...
# T-Student test conducted...
# T-statistic: -0.6619305189538429
# p-value: 0.513068640116957
# Brak podstaw do odrzucenia H0.
# ##########################################
# Total_com
# ------------------------------
# 1a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 2.3494561351511623
# p-value: 0.12532672488217686
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.297619047619051
# p-value: 0.5853789284609594
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.5564814814814838
# p-value: 0.21218114357772083
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 0.02286063569682712
# p-value: 0.8798200483537951
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.3352941176470665
# p-value: 0.5625582238835638
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.005681818181827225
# p-value: 0.9399140932267
# Brak podstaw do odrzucenia H0.
# ##########################################
# Avg_com
# ------------------------------
# 1a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.8295391227030324
# p-value: 0.3624058303300165
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.9642857142857082
# p-value: 0.32610945202048763
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2a
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 0.2083333333333428
# p-value: 0.6480768681391386
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.4628571428571462
# p-value: 0.4962917022310912
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3a
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.6278637770897859
# p-value: 0.4281399788324578
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.04297662694775436
# p-value: 0.835769288935973
# Brak podstaw do odrzucenia H0.
# ##########################################
# Num_com
# ------------------------------
# 1a
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 117.0
# p-value: 0.09708503093083724
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 1b
# Data have not at least length 3...
# Mann-Whitney test conducted...
# U-statistic: 27.5
# p-value: 0.5023771818084835
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2a
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 200.0
# p-value: 0.24442683860459047
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 86.0
# p-value: 0.20045930630231068
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3a
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 130.0
# p-value: 0.22505722700641528
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3b
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 106.5
# p-value: 0.4263731178018213
# Brak podstaw do odrzucenia H0.
# ##########################################
# Total_plt
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.9642857142857082
# p-value: 0.32610945202048763
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 11.571428571428584
# p-value: 0.0006697294490218247
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# 3b
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 0.5127840909090935
# p-value: 0.47393612178306677
# Brak podstaw do odrzucenia H0.
# ##########################################
# Avg_plt
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.011904761904759198
# p-value: 0.9131160800723842
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 10.565714285714293
# p-value: 0.0011520450981421793
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# 3b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.7514204545454533
# p-value: 0.38602687878277464
# Brak podstaw do odrzucenia H0.
# ##########################################
# Num_plt
# ------------------------------
# 1b
# Data have not at least length 3...
# Mann-Whitney test conducted...
# U-statistic: 31.0
# p-value: 0.2918238137183081
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 146.0
# p-value: 0.3294611277996039
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3b
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 102.0
# p-value: 0.3354530883486311
# Brak podstaw do odrzucenia H0.
# ##########################################
# Total_tab
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.047619047619051
# p-value: 0.08085559837005196
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 2.0628571428571405
# p-value: 0.15092695006671242
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 2.0511363636363598
# p-value: 0.1520926324815762
# Brak podstaw do odrzucenia H0.
# ##########################################
# Avg_tab
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.047619047619051
# p-value: 0.08085559837005196
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 2.892857142857153
# p-value: 0.0889730117018125
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.4545454545454533
# p-value: 0.22779999398822576
# Brak podstaw do odrzucenia H0.
# ##########################################
# Num_tab
# ------------------------------
# 1b
# Data have not at least length 3...
# Mann-Whitney test conducted...
# U-statistic: 11.5
# p-value: 0.32152419094523577
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 131.5
# p-value: 0.6738485531728337
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3b
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 138.5
# p-value: 0.7054052153386785
# Brak podstaw do odrzucenia H0.
# ##########################################
# Total_txt
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.0
# p-value: 1.0
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.02285714285714846
# p-value: 0.8798291600118151
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 4.458631443771784
# p-value: 0.034725308131750295
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ##########################################
# Avg_txt
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.10719581950427637
# p-value: 0.7433595231697815
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 0.1157142857142901
# p-value: 0.7337299956962424
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3b
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 6.283908599193249
# p-value: 0.012183908635559012
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ##########################################
# Num_txt
# ------------------------------
# 1b
# Data have not at least length 3...
# Mann-Whitney test conducted...
# U-statistic: 22.5
# p-value: 0.9088687650443987
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 134.0
# p-value: 0.605967078231484
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3b
# Conducting normality test...
# Mann-Whitney test conducted...
# U-statistic: 122.0
# p-value: 0.830200938198824
# Brak podstaw do odrzucenia H0.

# %% [markdown]
# Podsumowanie - każde AOI (każda grafika) osobno - poprawność:
#
# Istotne statystycznie:
# - całkowita długość fiksacji: mapa: 2a, 3a; wykres: 2b, tekst: 3b
# - średnia długość fiksacji: mapa: 2a, 3a; wykres: 2b, tekst: 3b

# %% [markdown]
# ### Testy:
#
# **H0:** Nie ma istotnej statystycznie zależności między trudnością a daną metryką dotyczącą wizyt.
#
# **H1:** Istnieje istotna statystycznie zależność między trudnością a daną metryką dotyczącą wizyt.
#
# **Poziom istotności:** $\alpha=0.05$
#
# Trudność vs całkowita, średnia długość wizyty

# %%
# kolekcje grafik
param_category = 'Diff'
for col in cols_continue:
    print('##########################################')
    print(col)
    for i, df in enumerate(dfs_coll):
        print('------------------------------')
        print(names_coll[i + 1])
        df = df.dropna()
        conduct_categorical_vs_quantitative_for_many_groups_test(df, col, param_category, ALPHA)
# Out:
# ##########################################
# Total
# ------------------------------
# Kolekcja wszystkie grafiki: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 15.264556905779841
# p-value: 0.004182818542384818
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Kolekcja wszystkie grafiki: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 15.799214945333006
# p-value: 0.00330076737027282
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Kolekcja wszystkie grafiki: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 3.8472853892044876
# p-value: 0.4270678591517916
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki A: z poleceniem:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 1.6357315778802786
# p-value: 0.8023562085774785
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki A: bez polecenia:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 2.0281840840518726
# p-value: 0.7305748801772425
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki A: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.185112949290876
# p-value: 0.7017556850330187
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki B: z poleceniem:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 15.101314915343494
# p-value: 0.004495630823175055
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Kolekcja grafiki B: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 15.28446718375227
# p-value: 0.004146160619469283
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Kolekcja grafiki B: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 4.816294670807623
# p-value: 0.3066713901226871
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 1: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.2002234351015395
# p-value: 0.6989883696773498
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 1: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.250525998391803
# p-value: 0.6897904382857432
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 1: tylko polecenie :
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.0781526517904174
# p-value: 0.782350564985732
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 2: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.2599395455493285
# p-value: 0.37196838103852464
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 2: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.325772878882663
# p-value: 0.3637089210979952
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 2: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.874675017608033
# p-value: 0.9281656510328621
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 3: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.5677157624983755
# p-value: 0.8145825437377464
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 3: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.8465113783353422
# p-value: 0.7639627345943696
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 3: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 4.8640363129584046
# p-value: 0.3015348488703433
# Brak podstaw do odrzucenia H0.
# ##########################################
# Avg
# ------------------------------
# Kolekcja wszystkie grafiki: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 10.420152506192137
# p-value: 0.03391482386085366
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Kolekcja wszystkie grafiki: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 5.116082122357287
# p-value: 0.2755927816794905
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja wszystkie grafiki: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 4.070964698249812
# p-value: 0.3964870067244792
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki A: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 10.637457543288134
# p-value: 0.030955310002452815
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Kolekcja grafiki A: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 8.913631449557492
# p-value: 0.06329491367541534
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki A: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 6.291974388539028
# p-value: 0.17837873418221864
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki B: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 5.126902029958842
# p-value: 0.27452263746493966
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki B: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 5.518207840621538
# p-value: 0.23813362569223637
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki B: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 4.096400448754876
# p-value: 0.3931166474520476
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 1: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.262147608489107
# p-value: 0.687668892283732
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 1: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.033731085987229
# p-value: 0.5521965386385564
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 1: tylko polecenie :
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.8712507160045075
# p-value: 0.5995540457783206
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 2: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 12.441182509902044
# p-value: 0.014355036623633372
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Kolekcja grafiki 2: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 9.833910777569319
# p-value: 0.04332032456470019
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Kolekcja grafiki 2: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.788339104698667
# p-value: 0.3097126241602574
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 3: z poleceniem:
# Conducting normality test...
# Conducting homogeneity variance test...
# Kruskal-Wallis test conducted...
# H: 3.3217154001883715
# p-value: 0.5054990167487026
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 3: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 2.230857032680981
# p-value: 0.6933841418220665
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 3: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 12.530974702283446
# p-value: 0.013810142758135933
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.

# %%
# sumy grafik
param_category = 'Diff'
for col in cols_continue:
    print('##########################################')
    print(col)
    for i, df in enumerate(dfs_sum):
        print('------------------------------')
        print(names_sum[i + 1])
        df = df.dropna()
        conduct_categorical_vs_quantitative_for_many_groups_test(df, col, param_category, ALPHA)
# Out:
# ##########################################
# Total
# ------------------------------
# Zsumowane wszystkie grafiki: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 7.851341463414656
# p-value: 0.7966369666835587
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane wszystkie grafiki: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 8.934390243902442
# p-value: 0.7085239399522983
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane wszystkie grafiki: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 11.351829268292704
# p-value: 0.4990315971996887
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki A: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 10.82546904315194
# p-value: 0.14641523824499747
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki A: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 12.368105065666043
# p-value: 0.08908503916093624
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki A: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 7.406848030018779
# p-value: 0.38778187640445944
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki B: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 13.37914634146341
# p-value: 0.14618726417718855
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki B: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 12.623841463414664
# p-value: 0.18037863417231811
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki B: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 7.583963414634155
# p-value: 0.5765534755423487
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 1: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.465017421602795
# p-value: 0.6286874237545249
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 1: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.065949477351907
# p-value: 0.6898189387112403
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 1: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 5.775644599303121
# p-value: 0.32866540452745746
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 2: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 22.813048780487804
# p-value: 0.0008615729815551085
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Zsumowane grafiki 2: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 23.300609756097543
# p-value: 0.0007018014352684199
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Zsumowane grafiki 2: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.453597560975609
# p-value: 0.6155369262339649
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 3: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 15.924738675958196
# p-value: 0.025812924174543984
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Zsumowane grafiki 3: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 16.13641114982579
# p-value: 0.023898893467345028
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Zsumowane grafiki 3: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 5.279616724738673
# p-value: 0.6258815948317429
# Brak podstaw do odrzucenia H0.
# ##########################################
# Avg
# ------------------------------
# Zsumowane wszystkie grafiki: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 8.946341463414655
# p-value: 0.7075066341342291
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane wszystkie grafiki: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 7.556097560975616
# p-value: 0.8187874265965797
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane wszystkie grafiki: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 12.675000000000011
# p-value: 0.39309882455448797
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki A: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 11.823123827392124
# p-value: 0.10652763773098949
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki A: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 11.775422138836774
# p-value: 0.10819033731012614
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki A: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 6.012102448634959
# p-value: 0.5383369201233713
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki B: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 9.270243902439034
# p-value: 0.4127116656445741
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki B: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 11.877682926829266
# p-value: 0.22029313969610698
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki B: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.800548780487787
# p-value: 0.8513367417211217
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 1: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.224642857142868
# p-value: 0.8172685865667765
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 1: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.544817073170748
# p-value: 0.7697309224287503
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 1: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.3321080139372867
# p-value: 0.8015397596523641
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 2: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 15.616585365853666
# p-value: 0.01596676279611712
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Zsumowane grafiki 2: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 15.114634146341444
# p-value: 0.019383614406062167
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Zsumowane grafiki 2: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 5.527073170731711
# p-value: 0.4781906024340218
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 3: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 6.283362369337965
# p-value: 0.5070795665617018
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 3: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 8.817073170731703
# p-value: 0.2660576897955384
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 3: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.558536585365857
# p-value: 0.713657499651068
# Brak podstaw do odrzucenia H0.

# %% [markdown]
# Trudność vs liczba wizyt - stosujemy ANOVA / Kruskala - Wallisa (mamy wiele wartości)

# %%
# kolekcje grafik
param_category = 'Diff'
col = 'Num'
for i, df in enumerate(dfs_coll):
    print('------------------------------')
    print(names_coll[i + 1])
    df = df.dropna()
    conduct_categorical_vs_quantitative_for_many_groups_test(df, col, param_category, ALPHA)
# Out:
# ------------------------------
# Kolekcja wszystkie grafiki: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 16.529956033971384
# p-value: 0.002384569843696328
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Kolekcja wszystkie grafiki: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 5.258785748848701
# p-value: 0.26175993016434007
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja wszystkie grafiki: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 7.628580881277815
# p-value: 0.10617126612252735
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki A: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 11.478987424971434
# p-value: 0.021676882535788807
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Kolekcja grafiki A: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 8.11635701139441
# p-value: 0.08740768542019559
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki A: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.90536340539716
# p-value: 0.41896500052229924
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki B: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 12.003348647522639
# p-value: 0.017326381198990767
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# Kolekcja grafiki B: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.907750430054264
# p-value: 0.7527210850779894
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki B: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 3.280582532492723
# p-value: 0.5120146571787101
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 1: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.072699859776171
# p-value: 0.3962563943251394
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 1: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.8519887424362418
# p-value: 0.7629582401132368
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 1: tylko polecenie :
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 1.4323968846923087
# p-value: 0.6979586004253686
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 2: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 5.326128766035728
# p-value: 0.25544087048516684
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 2: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.692545528712032
# p-value: 0.3203229268649607
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 2: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.3977634174145273
# p-value: 0.49359289366069425
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 3: z poleceniem:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 5.112357164645379
# p-value: 0.2759620159980891
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 3: bez polecenia:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 5.768039297359285
# p-value: 0.21715388281032585
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Kolekcja grafiki 3: tylko polecenie:
# Conducting normality test...
# Kruskal-Wallis test conducted...
# H: 2.592716283047484
# p-value: 0.6281139435195178
# Brak podstaw do odrzucenia H0.

# %%
# sumy grafik
param_category = 'Diff'
col = 'Num'
for i, df in enumerate(dfs_sum):
    print('------------------------------')
    print(names_sum[i + 1])
    df = df.dropna()
    conduct_categorical_vs_quantitative_for_many_groups_test(df, col, param_category, ALPHA)
# Out:
# ------------------------------
# Zsumowane wszystkie grafiki: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 11.509416408232319
# p-value: 0.4858379343996371
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane wszystkie grafiki: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 13.373932308852648
# p-value: 0.3424574937538146
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane wszystkie grafiki: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 11.689330730881384
# p-value: 0.47094136567178235
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki A: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.304466308040769
# p-value: 0.7441166436430634
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki A: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 7.529382946181025
# p-value: 0.3759126942767519
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki A: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.7005983791933845
# p-value: 0.6964464511344333
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki B: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 9.936223074028767
# p-value: 0.35567298074481196
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki B: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 8.29843646903576
# p-value: 0.5043733067993108
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki B: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 8.844795783926244
# p-value: 0.45172265169004044
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 1: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 5.693399751143411
# p-value: 0.3372044450614614
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 1: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 6.3778264418216954
# p-value: 0.27117057557830104
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 1: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 7.027844022078156
# p-value: 0.21857773608114967
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 2: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 11.22701438510717
# p-value: 0.08160861471224379
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 2: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 8.657593557555652
# p-value: 0.19377011562030788
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 2: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.095495783589153
# p-value: 0.6637548933582265
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 3: z poleceniem:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 12.406697520083835
# p-value: 0.08795294208732585
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 3: bez polecenia:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 7.212218062894429
# p-value: 0.4071234897280429
# Brak podstaw do odrzucenia H0.
# ------------------------------
# Zsumowane grafiki 3: tylko polecenie:
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 7.0069927942786645
# p-value: 0.42815213323812046
# Brak podstaw do odrzucenia H0.

# %% [markdown]
# Podsumowanie - trudność:
#
# Istotne statystycznie:
#
# - całkowita długość wizyty:
#     - kolekcje: wszystkie (z poleceniem, bez polecenia), B (z poleceniem, bez polecenia)
#     - sumy: 2 (z poleceniem, bez polecenia), 3 (z poleceniem, bez polecenia)
# - średnia długość wizyty:
#     - kolekcje: wszystkie (z poleceniem), A (z poleceniem), 2 (z poleceniem, bez polecenia), 3 (tylko polecenie)
#     - sumy: 2 (z poleceniem, bez polecenia)
# - liczba wizyt:
#     - kolekcje: wszystkie (z poleceniem), A (z poleceniem), B (z poleceniem)

# %% [markdown]
# Test: poszczególne grafiki - trudność

# %%
columns_sample = ['Total_map', 'Avg_map', 'Num_map', 'Total_com', 'Avg_com', 'Num_com', 'Total_plt', 'Avg_plt', 'Num_plt', 'Total_tab', 'Avg_tab', 'Num_tab',  'Total_txt', 'Avg_txt', 'Num_txt']

param_category = 'Diff'
for col in columns_sample:
    print('##########################################')
    print(col)
    for i, df in enumerate(dfs_samples):
        if col not in df.columns:
            continue
        print('------------------------------')
        print(names_samples[i+1])
        df = df.dropna()
        conduct_categorical_vs_quantitative_for_many_groups_test(df, col, param_category, ALPHA)
# Out:
# ##########################################
# Total_map
# ------------------------------
# 1a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 9.154338549075405
# p-value: 0.05735542040881985
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.2889492753623131
# p-value: 0.9620932463292112
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 20.60389610389612
# p-value: 0.00037937972288406776
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 10.229934363721034
# p-value: 0.03672756266297712
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# 3a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 17.549261667682714
# p-value: 0.0015112162405531064
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 7.218204775022954
# p-value: 0.12479670079562893
# Brak podstaw do odrzucenia H0.
# ##########################################
# Avg_map
# ------------------------------
# 1a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 7.216724243040034
# p-value: 0.12486905936286453
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.2346014492753596
# p-value: 0.3568491138098704
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 18.09030969030968
# p-value: 0.0011849384675523226
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 6.27113245298122
# p-value: 0.17979427968551995
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 9.14355144618304
# p-value: 0.05760983849360749
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.0589703856749395
# p-value: 0.3980839003137982
# Brak podstaw do odrzucenia H0.
# ##########################################
# Num_map
# ------------------------------
# 1a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.3412197965239616
# p-value: 0.5024279534135099
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 5.803768226517472
# p-value: 0.12155756681322419
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 6.896609606609598
# p-value: 0.14145385576074046
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 5.840636110681711
# p-value: 0.21136997007467276
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 9.696871857301637
# p-value: 0.04585542962634048
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.061436901883125
# p-value: 0.547597245446008
# Brak podstaw do odrzucenia H0.
# ##########################################
# Total_com
# ------------------------------
# 1a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.0434245067321504
# p-value: 0.7277720115188878
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.976449275362313
# p-value: 0.1735297890463601
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.919540459540471
# p-value: 0.4170043650364249
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.74493665589708
# p-value: 0.3144835812266862
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.685463659147871
# p-value: 0.45024368168894024
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.389290633608823
# p-value: 0.35587730831662956
# Brak podstaw do odrzucenia H0.
# ##########################################
# Avg_com
# ------------------------------
# 1a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.5818612922347397
# p-value: 0.96505782539302
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.3297101449275317
# p-value: 0.5068531379329233
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.835974025974039
# p-value: 0.5856390517763461
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 5.331756702681076
# p-value: 0.2549187567893083
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.582994648784137
# p-value: 0.4653715328207402
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.230795118925273
# p-value: 0.6933954599641804
# Brak podstaw do odrzucenia H0.
# ##########################################
# Num_com
# ------------------------------
# 1a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.0968779917030123
# p-value: 0.8947672308136934
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.0971862033195
# p-value: 0.2511592024968475
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.145067978361813
# p-value: 0.3867288937453142
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.0638295696285467
# p-value: 0.7240200507422352
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3a
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 7.9097210278284384
# p-value: 0.09494177242844375
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.665356592582628
# p-value: 0.3233881344939068
# Brak podstaw do odrzucenia H0.
# ##########################################
# Total_plt
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.828804347826079
# p-value: 0.6086869369317194
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.4653701480592503
# p-value: 0.48316338824424243
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 6.259182736455472
# p-value: 0.1806104262543562
# Brak podstaw do odrzucenia H0.
# ##########################################
# Avg_plt
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.0172101449275317
# p-value: 0.568842369637268
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 5.067843137254897
# p-value: 0.2804069359128703
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.7095385674931407
# p-value: 0.44674011341637654
# Brak podstaw do odrzucenia H0.
# ##########################################
# Num_plt
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.9541815704309309
# p-value: 0.5819707409141441
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.77085335150798
# p-value: 0.9423123153267581
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.1131619490189184
# p-value: 0.5390698279690599
# Brak podstaw do odrzucenia H0.
# ##########################################
# Total_tab
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.506340579710141
# p-value: 0.6808077029449431
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 9.669547819127658
# p-value: 0.04637761405567247
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.488263314967881
# p-value: 0.34394141644855275
# Brak podstaw do odrzucenia H0.
# ##########################################
# Avg_tab
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.285326086956516
# p-value: 0.34969020761790887
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 11.24772308923572
# p-value: 0.02391658733943681
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.8009354912764053
# p-value: 0.5916712417367813
# Brak podstaw do odrzucenia H0.
# ##########################################
# Num_tab
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.3809583752937207
# p-value: 0.33653275787057985
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.355103744958151
# p-value: 0.5002491644162312
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 0.7649068129199273
# p-value: 0.9430899111841612
# Brak podstaw do odrzucenia H0.
# ##########################################
# Total_txt
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.226499423298721
# p-value: 0.23802214597289728
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 5.254277711084427
# p-value: 0.262187675718486
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 2.5790177967530856
# p-value: 0.6305444927459485
# Brak podstaw do odrzucenia H0.
# ##########################################
# Avg_txt
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 4.305342725325421
# p-value: 0.2303244336146096
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.767442977190882
# p-value: 0.4383928533886682
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 3.1876713134276633
# p-value: 0.5269245402960707
# Brak podstaw do odrzucenia H0.
# ##########################################
# Num_txt
# ------------------------------
# 1b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.8881638571687454
# p-value: 0.5959398992862137
# Brak podstaw do odrzucenia H0.
# ------------------------------
# 2b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 14.184091601974961
# p-value: 0.006730107099787718
# Istnieją podstawy do odrzucenia H0, przyjmujemy hipotezę H1.
# ------------------------------
# 3b
# Data have not at least length 3...
# Kruskal-Wallis test conducted...
# H: 1.349549585696108
# p-value: 0.8529143996455186
# Brak podstaw do odrzucenia H0.

# %% [markdown]
# Podsumowanie - każde AOI (każda grafika) osobno - trudność:
#
# Istotne statystycznie:
# - całkowita długość wizyty: mapa: 2a, 2b, 3a; tabela: 2b
# - średnia długość wizyty: mapa: 2a, tabela: 2b
# - liczba wizyt: mapa: 3a; tekst: 2b
